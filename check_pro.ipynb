# %%
import json
import random

def analyze_text(context, question, answer, answer_start, window_size=12):
    """
    Analyzes text and prints in the specified format
    """
    print(f"Question: {question}")
    print(f"Answer: {answer}")
    print(f"Start position: {answer_start}")
    print("Neighboring characters:", end=" ")
    
    text_to_analyze = context[answer_start:answer_start + window_size]
    chars = []
    
    for i in range(window_size):
        current_pos = answer_start + i
        if i < len(text_to_analyze):
            char = text_to_analyze[i]
            if char == ' ':
                chars.append(f"{current_pos}: ")
            else:
                chars.append(f"{current_pos}: {char}")
        else:
            chars.append(f"{current_pos}:")
    
    print(" ".join(chars))
    
    start_idx = max(0, answer_start - 5)
    end_idx = min(len(context), answer_start + len(answer) + 5)
    snippet = context[start_idx:end_idx]
    print(f"Context snippet: {snippet}")
    print("-" * 47)

def process_squad_dataset(file_path):
    """
    Processes the dataset with exactly one question per article
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        for idx, article in enumerate(data['data'], 1):
            title = article.get('title', 'Untitled')
            print(f"{idx}. {title}:")
            
            # Collect all QAs from all paragraphs in the article
            all_qas = []
            for paragraph in article['paragraphs']:
                all_qas.extend([(qa, paragraph['context']) for qa in paragraph['qas']])
            
            if all_qas:
                # Select one random QA pair from all QAs in the article
                qa, context = random.choice(all_qas)
                question = qa.get('question', 'Unknown question')
                
                # Check if this is an impossible answer case
                is_impossible = qa.get('is_impossible', False)
                
                if is_impossible:
                    plausible_answers = qa.get('plausible_answers', [])
                    if plausible_answers:
                        ans = plausible_answers[0]  # Take first plausible answer
                        print(f"Question: {question}")
                        print(f"Plausible Answer: {ans.get('text', 'No text')}")
                        print(f"Start position: {ans.get('answer_start', 'N/A')}")
                        
                        answer_start = ans['answer_start']
                        text_to_analyze = context[answer_start:answer_start + 12]
                        chars = []
                        print("Neighboring characters:", end=" ")
                        for i in range(12):
                            current_pos = answer_start + i
                            if i < len(text_to_analyze):
                                char = text_to_analyze[i]
                                if char == ' ':
                                    chars.append(f"{current_pos}: ")
                                else:
                                    chars.append(f"{current_pos}: {char}")
                            else:
                                chars.append(f"{current_pos}:")
                        print(" ".join(chars))
                        
                        start_idx = max(0, answer_start - 5)
                        end_idx = min(len(context), answer_start + len(ans['text']) + 5)
                        snippet = context[start_idx:end_idx]
                        print(f"Context snippet: {snippet}")
                else:
                    if 'answers' in qa and qa['answers']:
                        answer_info = qa['answers'][0]
                        analyze_text(
                            context=context,
                            question=question,
                            answer=answer_info['text'],
                            answer_start=answer_info['answer_start']
                        )
                    else:
                        print(f"Question: {question}")
                        print("Answer: No answer provided")
                print("-" * 47)

    except FileNotFoundError:
        print(f"Error: Could not find file at {file_path}")
    except json.JSONDecodeError:
        print(f"Error: File at {file_path} is not valid JSON")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# %%
    
# Example usage
if __name__ == "__main__":
    # Replace with your dataset path
    #dataset_path = "../alpha 2.0/valid_og_nums.json"
    dataset_path = "/Users/santhoshrishimarkonda/Downloads/SQUAD TEL DATA/squad2.0_telugu_train.json"
    process_squad_dataset(dataset_path)
# Out:
# 1. బియాన్స్ :
# Question: పెప్సి ప్రపంచ ప్రచారంలో చేరడానికి నిక్కీ మినాజ్ను ఏది ప్రభావితం చేసింది?
# Answer: బియాన్స్ యొక్క పెప్సి వాణిజ్య ప్రకటనను
# Start position: 561
# Neighboring characters: 561: బ 562: ి 563: య 564: ా 565: న 566: ్ 567: స 568: ్ 569:  570: య 571: ొ 572: క
# Context snippet: ంది. బియాన్స్ యొక్క పెప్సి వాణిజ్య ప్రకటనను చూడట
# -----------------------------------------------
# -----------------------------------------------
# 2. ఫ్రెడెరిక్ _ చోపిన్ :
# Question: ఆయన ఎక్కువగా ఏ వాయిద్యం కోసం స్వరపరిచారు?
# Answer: సోలో పియానో
# Start position: 324
# Neighboring characters: 324: స 325: ో 326: ల 327: ో 328:  329: ప 330: ి 331: య 332: ా 333: న 334: ో 335:
# Context snippet: నంగా సోలో పియానో కోసం
# -----------------------------------------------
# -----------------------------------------------
# 3. మింగ్ రాజవంశం సమయంలో చైనా-టిబెటన్ సంబంధాలు :
# Question: హాంగ్వు చక్రవర్తిగా ఎవరు పాలించారు?
# Answer: జు యువాన్జాంగ్
# Start position: 115
# Neighboring characters: 115: జ 116: ు 117:  118: య 119: ు 120: వ 121: ా 122: న 123: ్ 124: జ 125: ా 126: ం
# Context snippet: ంది. జు యువాన్జాంగ్ తరువ
# -----------------------------------------------
# -----------------------------------------------
# 4. ఐప్యాడ్ :
# Question: ఐపాడ్ బ్యాటరీలు పనిచేయకపోయినప్పుడు కొనుగోలు చేయమని ఆపిల్ మొదట వినియోగదారులకు ఏమి చెప్పింది?
# Answer: పునరుద్ధరించిన రీప్లేస్మెంట్ ఐపాడ్ను
# Start position: 371
# Neighboring characters: 371: ప 372: ు 373: న 374: ర 375: ు 376: ద 377: ్ 378: ధ 379: ర 380: ి 381: ం 382: చ
# Context snippet: చుతో పునరుద్ధరించిన రీప్లేస్మెంట్ ఐపాడ్ను కొను
# -----------------------------------------------
# -----------------------------------------------
# 5. ది _ లెజెండ్ _ ఆఫ్ _ జేల్డాః _ ట్విలైట్ _ ప్రిన్సెస్ :
# Question: ది లెజెండ్ ఆఫ్ జేల్డాలో మూడు ప్రధాన కార్యకలాపాలు ఏమిటిః ట్విలైట్ ప్రిన్సెస్?
# Answer: పోరాటం, అన్వేషణ మరియు వస్తువుల సేకరణపై
# Start position: 49
# Neighboring characters: 49: ప 50: ో 51: ర 52: ా 53: ట 54: ం 55: , 56:  57: అ 58: న 59: ్ 60: వ
# Context snippet: నేది పోరాటం, అన్వేషణ మరియు వస్తువుల సేకరణపై దృష్
# -----------------------------------------------
# -----------------------------------------------
# 6. స్పెక్టర్ (2015-చిత్రం) :
# Question: స్పెక్టర్ ఏ విభాగంలో అకాడమీ అవార్డును గెలుచుకుంది?
# Plausible Answer: ఉత్తమ ఒరిజినల్ సాంగ్కు
# Start position: 681
# Neighboring characters: 681: ఉ 682: త 683: ్ 684: త 685: మ 686:  687: ఒ 688: ర 689: ి 690: జ 691: ి 692: న
# Context snippet:  ఇది ఉత్తమ ఒరిజినల్ సాంగ్కు గోల్
# -----------------------------------------------
# 7. 2008 సిచువాన్ భూకంపం :
# Question: దక్షిణ కొరియా, జపాన్ మరియు ఇతరుల నుండి సమూహాలు చైనాకు ఎప్పుడు వచ్చాయి?
# Answer: మే 16న,
# Start position: 0
# Neighboring characters: 0: మ 1: ే 2:  3: 1 4: 6 5: న 6: , 7:  8: ద 9: క 10: ్ 11: ష
# Context snippet: మే 16న, దక్ష
# -----------------------------------------------
# -----------------------------------------------
# 8. న్యూయార్క్ _ సిటీ :
# Question: క్వీన్స్ లాంగ్ ఐలాండ్ యొక్క ఏ భాగంలో ఉంది?
# Answer: పశ్చిమ చివరలో
# Start position: 218
# Neighboring characters: 218: ప 219: శ 220: ్ 221: చ 222: ి 223: మ 224:  225: చ 226: ి 227: వ 228: ర 229: ల
# Context snippet: ొక్క పశ్చిమ చివరలో ఉన్న
# -----------------------------------------------
# -----------------------------------------------
# 9. ఒక మోకింగ్బర్డ్ను చంపడానికి (_ K) :
# Question: టామ్ రాబిన్సన్ విచారణను జెమ్, స్కౌట్ మరియు దిల్ ఎక్కడ గమనిస్తారు?
# Answer: బాల్కనీ
# Start position: 184
# Neighboring characters: 184: బ 185: ా 186: ల 187: ్ 188: క 189: న 190: ీ 191:  192: న 193: ు 194: ం 195: డ
# Context snippet: ంగుల బాల్కనీ నుండ
# -----------------------------------------------
# -----------------------------------------------
# 10. సౌరశక్తి (_ E) :
# Question: సోలార్ వాటర్ క్రిమిసంహారక గురించి ప్రపంచ ఆరోగ్య సంస్థ ఏమి చెబుతోంది?
# Answer: గృహ నీటి శుద్ధి మరియు సురక్షిత నిల్వ కోసం ఆచరణీయమైన పద్ధతిగా
# Start position: 303
# Neighboring characters: 303: గ 304: ృ 305: హ 306:  307: న 308: ీ 309: ట 310: ి 311:  312: శ 313: ు 314: ద
# Context snippet:  ఇది గృహ నీటి శుద్ధి మరియు సురక్షిత నిల్వ కోసం ఆచరణీయమైన పద్ధతిగా ప్రప
# -----------------------------------------------
# -----------------------------------------------
# 11. కాన్యే _ వెస్ట్ :
# Question: వివిధ కార్యక్రమాలలో కాన్యే వెస్ట్ ప్రదర్శనను నిరోధించడానికి సంగీత అభిమానులు ఏ వెబ్సైట్ను ఉపయోగిస్తున్నారు?
# Answer: Change.org
# Start position: 89
# Neighboring characters: 89: C 90: h 91: a 92: n 93: g 94: e 95: . 96: o 97: r 98: g 99:  100: వ
# Context snippet: తంగా Change.org వైపు
# -----------------------------------------------
# -----------------------------------------------
# 12. బౌద్ధమతం :
# Question: కొంతమంది సామాన్య ప్రజలు మొత్తం ఎనిమిది విషయాలలో ప్రావీణ్యం పొందారని ఆధారాలు చూపించాయి.
# Answer: చాన్
# Start position: 369
# Neighboring characters: 369: చ 370: ా 371: న 372: ్ 373:  374: ( 375: జ 376: ె 377: న 378: ్ 379: ) 380:
# Context snippet: కానీ చాన్ (జెన
# -----------------------------------------------
# -----------------------------------------------
# 13. అమెరికన్ ఐడల్ (_ I) :
# Question: అమెరికన్ ఐడల్ యొక్క ఏ సీజన్ దాని పర్యటనలో అత్యధిక లాభాలను ఆర్జించింది?
# Answer: ఉంది. సీజన్
# Start position: 357
# Neighboring characters: 357: ఉ 358: ం 359: ద 360: ి 361: . 362:  363: స 364: ీ 365: జ 366: న 367: ్ 368:
# Context snippet: ర్గా ఉంది. సీజన్ ఐదు
# -----------------------------------------------
# -----------------------------------------------
# 14. కుక్క. :
# Question: చాలా కుక్కలు తోడేళ్ళ కంటే తక్కువ ఏమి చూపిస్తాయి?
# Answer: భయం మరియు దూకుడు
# Start position: 663
# Neighboring characters: 663: భ 664: య 665: ం 666:  667: మ 668: ర 669: ి 670: య 671: ు 672:  673: ద 674: ూ
# Context snippet: ్కువ భయం మరియు దూకుడు చూపు
# -----------------------------------------------
# -----------------------------------------------
# 15. 2008 _ సమ్మర్ _ ఒలింపిక్స్ _ టార్చ్ _ రిలే :
# Question: ఏ ఫ్రెంచ్ కంపెనీని బహిష్కరించారు?
# Answer: క్యారీఫోర్ను
# Start position: 216
# Neighboring characters: 216: క 217: ్ 218: య 219: ా 220: ర 221: ీ 222: ఫ 223: ో 224: ర 225: ్ 226: న 227: ు
# Context snippet: ర్ట్ క్యారీఫోర్ను బహిష
# -----------------------------------------------
# -----------------------------------------------
# 16. జీనోమ్ :
# Question: జన్యువు యొక్క ముఖ్యమైన మరియు గుర్తించదగిన భాగాలను జాబితా చేసే పదానికి పదం ఏమిటి?
# Answer: జన్యువును మ్యాప్
# Start position: 227
# Neighboring characters: 227: జ 228: న 229: ్ 230: య 231: ు 232: వ 233: ు 234: న 235: ు 236:  237: మ 238: ్
# Context snippet: మానవ జన్యువును మ్యాప్ చేయడ
# -----------------------------------------------
# -----------------------------------------------
# 17. సమగ్ర పాఠశాల (_ S) :
# Question: వాల్వర్త్ పాఠశాలను ఎవరు స్థాపించారు?
# Answer: లండన్ కౌంటీ కౌన్సిల్
# Start position: 88
# Neighboring characters: 88: ల 89: ం 90: డ 91: న 92: ్ 93:  94: క 95: ౌ 96: ం 97: ట 98: ీ 99:
# Context snippet: 6లో, లండన్ కౌంటీ కౌన్సిల్ ఏర్ప
# -----------------------------------------------
# -----------------------------------------------
# 18. రిపబ్లిక్ _ ఆఫ్ _ ది _ కాంగో :
# Question: వాయువ్య కామెరూన్ సరిహద్దులో ఏది ఉంది?
# Plausible Answer: సెంట్రల్ ఆఫ్రికన్ రిపబ్లిక్;
# Start position: 250
# Neighboring characters: 250: స 251: ె 252: ం 253: ట 254: ్ 255: ర 256: ల 257: ్ 258:  259: ఆ 260: ఫ 261: ్
# Context snippet: యంలో సెంట్రల్ ఆఫ్రికన్ రిపబ్లిక్; తూర్
# -----------------------------------------------
# 19. ప్రధాన మంత్రి (_ m) :
# Question: ప్రధానమంత్రి అనే బిరుదును మొదటిసారిగా ఎప్పుడు ఉపయోగించారు?
# Answer: 1625లో
# Start position: 82
# Neighboring characters: 82: 1 83: 6 84: 2 85: 5 86: ల 87: ో 88:  89: ఫ 90: ్ 91: ర 92: ా 93: న
# Context snippet: ల్యూ 1625లో ఫ్రా
# -----------------------------------------------
# -----------------------------------------------
# 20. ఇన్స్టిట్యూట్ _ ఆఫ్ _ టెక్నాలజీ :
# Question: డెబ్బైలు, ఎనభైల, తొంభైల ప్రారంభంలో ఏ వ్యవస్థలో సాంకేతిక సంస్థలు భాగంగా ఉండేవి?
# Answer: కాలేజ్ ఆఫ్ అడ్వాన్స్డ్ ఎడ్యుకేషన్ సిస్టమ్లో
# Start position: 182
# Neighboring characters: 182: క 183: ా 184: ల 185: ే 186: జ 187: ్ 188:  189: ఆ 190: ఫ 191: ్ 192:  193: అ
# Context snippet:  అవి కాలేజ్ ఆఫ్ అడ్వాన్స్డ్ ఎడ్యుకేషన్ సిస్టమ్లో భాగం
# -----------------------------------------------
# -----------------------------------------------
# 21. వెబ్యాక్ యంత్రం (_ M) :
# Question: యజమానులు దేనికి ఆసక్తి చూపరు?
# Plausible Answer: "సేకరణలో వారి సామగ్రిని కోరుకోని వ్యక్తుల వెబ్ సైట్లు లేదా ఇతర ఇంటర్నెట్ పత్రాలను భద్రపరచడం లేదా అందించడంలో ఇంటర్నెట్
# Start position: 227
# Neighboring characters: 227: " 228: స 229: ే 230: క 231: ర 232: ణ 233: ల 234: ో 235:  236: వ 237: ా 238: ర
# Context snippet: ందిః "సేకరణలో వారి సామగ్రిని కోరుకోని వ్యక్తుల వెబ్ సైట్లు లేదా ఇతర ఇంటర్నెట్ పత్రాలను భద్రపరచడం లేదా అందించడంలో ఇంటర్నెట్ ఆర్క
# -----------------------------------------------
# 22. డచ్ రిపబ్లిక్ (_ R) :
# Question: నెదర్లాండ్స్ ప్రజలు రెండవ ఫిలిప్కు వ్యతిరేకంగా ఎందుకు లేచారు?
# Answer: అధిక పన్నులు, ప్రభుత్వం ద్వారా ప్రొటెస్టంట్లను హింసించడం మరియు ప్రావిన్సుల వికేంద్రీకృత-మధ్యయుగ ప్రభుత్వ నిర్మాణాలను ఆధునీకరించడానికి మరియు కేంద్రీకరించడానికి ఫిలిప్ చేసిన ప్రయత్నాల
# Start position: 347
# Neighboring characters: 347: అ 348: ధ 349: ి 350: క 351:  352: ప 353: న 354: ్ 355: న 356: ు 357: ల 358: ు
# Context snippet: ్స్, అధిక పన్నులు, ప్రభుత్వం ద్వారా ప్రొటెస్టంట్లను హింసించడం మరియు ప్రావిన్సుల వికేంద్రీకృత-మధ్యయుగ ప్రభుత్వ నిర్మాణాలను ఆధునీకరించడానికి మరియు కేంద్రీకరించడానికి ఫిలిప్ చేసిన ప్రయత్నాల కారణ
# -----------------------------------------------
# -----------------------------------------------
# 23. సింబయోసిస్ :
# Question: ఒక బయోట్రోఫిక్ జీవి పేరు పెట్టండి.
# Answer: ఒక సభ్యుడు
# Start position: 33
# Neighboring characters: 33: ఒ 34: క 35:  36: స 37: భ 38: ్ 39: య 40: ు 41: డ 42: ు 43:  44: ప
# Context snippet: లోని ఒక సభ్యుడు ప్రయ
# -----------------------------------------------
# -----------------------------------------------
# 24. కెనడియన్ _ సాయుధ _ దళాలు :
# Question: ఇతర సైనిక దళాలతో పోలిస్తే కెనడియన్ దళాలు పరిమాణంలో ఎలా ఉన్నాయి?
# Answer: పరిమాణంలో 74వ స్థానంలో
# Start position: 161
# Neighboring characters: 161: ప 162: ర 163: ి 164: మ 165: ా 166: ణ 167: ం 168: ల 169: ో 170:  171: 7 172: 4
# Context snippet: స్తే పరిమాణంలో 74వ స్థానంలో ఉన్న
# -----------------------------------------------
# -----------------------------------------------
# 25. కార్డినల్ _ (కాథలిక్కులు) :
# Question: కార్డినల్స్ ప్రభావం ద్వారా ఎవరు తమను తాము పునరుద్ఘాటించుకోలేదు?
# Plausible Answer: ఫ్రెంచ్ రాజులు,
# Start position: 39
# Neighboring characters: 39: ఫ 40: ్ 41: ర 42: ె 43: ం 44: చ 45: ్ 46:  47: ర 48: ా 49: జ 50: ు
# Context snippet: యంగా ఫ్రెంచ్ రాజులు, కొన్
# -----------------------------------------------
# 26. ఇరానియన్ భాషలు (_ L) :
# Question: మణిచియన్ పత్రాల రచన దేనితో సమానంగా ఉంది?
# Answer: సిరియాక్ లిపికి
# Start position: 415
# Neighboring characters: 415: స 416: ి 417: ర 418: ి 419: య 420: ా 421: క 422: ్ 423:  424: ల 425: ి 426: ప
# Context snippet: థాలు సిరియాక్ లిపికి దగ్గ
# -----------------------------------------------
# -----------------------------------------------
# 27. లైటింగ్ :
# Question: డేసిమీటర్ ఏ రకమైన వ్యక్తిగత మీటర్?
# Answer: సిర్కాడియన్ లైట్ మీటర్
# Start position: 95
# Neighboring characters: 95: స 96: ి 97: ర 98: ్ 99: క 100: ా 101: డ 102: ి 103: య 104: న 105: ్ 106:
# Context snippet: తిగత సిర్కాడియన్ లైట్ మీటర్ అభివ
# -----------------------------------------------
# -----------------------------------------------
# 28. యునైటెడ్ స్టేట్స్ రాజ్యాంగం కింద అధికారాల విభజన :
# Question: సుప్రీంకోర్టుకు రాష్ట్రపతి నియామకాలను ఎవరు ఆమోదించాలి?
# Answer: సెనేట్
# Start position: 150
# Neighboring characters: 150: స 151: ె 152: న 153: ే 154: ట 155: ్ 156:  157: స 158: ల 159: హ 160: ా 161:
# Context snippet: ులను సెనేట్ సలహా
# -----------------------------------------------
# -----------------------------------------------
# 29. ఆర్కిటెక్చర్ :
# Question: లీ కార్బూసియర్ వృత్తి ఏమిటి?
# Answer: వాస్తుశిల్పి
# Start position: 88
# Neighboring characters: 88: వ 89: ా 90: స 91: ్ 92: త 93: ు 94: శ 95: ి 96: ల 97: ్ 98: ప 99: ి
# Context snippet: ్యాత వాస్తుశిల్పి లీ క
# -----------------------------------------------
# -----------------------------------------------
# 30. మానవ అభివృద్ధి సూచిక (_ D) :
# Question: కళ్ళు దేనిని సూచిస్తాయి?
# Plausible Answer: పాఠశాల సంవత్సరాలు (25 సంవత్సరాలు
# Start position: 38
# Neighboring characters: 38: ప 39: ా 40: ఠ 41: శ 42: ా 43: ల 44:  45: స 46: ం 47: వ 48: త 49: ్
# Context snippet: సగటు పాఠశాల సంవత్సరాలు (25 సంవత్సరాలు లేదా
# -----------------------------------------------
# 31. దక్షిణ _ ఐరోపా :
# Question: ఏ సంవత్సరంలో క్రొయేషియా యూరోపియన్ యూనియన్లో చేరింది?
# Answer: (2013).
# Start position: 657
# Neighboring characters: 657: ( 658: 2 659: 0 660: 1 661: 3 662: ) 663: . 664:  665: 666: 667: 668:
# Context snippet: షియా (2013).
# -----------------------------------------------
# -----------------------------------------------
# 32. బిబిసి _ టెలివిజన్ :
# Question: దాని కార్యక్రమాలలో బిబిసి ఇతర కంటెంట్ నిర్మాతల నుండి ఎంత పొందాలి?
# Answer: 25 శాతం
# Start position: 385
# Neighboring characters: 385: 2 386: 5 387:  388: శ 389: ా 390: త 391: ం 392:  393: మ 394: ూ 395: ల 396: ం
# Context snippet: తిలో 25 శాతం మూలం
# -----------------------------------------------
# -----------------------------------------------
# 33. ఆర్నాల్డ్ _ స్క్వార్జెనెగర్ :
# Question: 2013 నాటి ది లాస్ట్ స్టాండ్ స్క్వార్జెనెగర్ యొక్క మొదటి ప్రధాన పాత్రను ఎంతకాలం గుర్తించింది?
# Answer: 10 సంవత్సరాలలో
# Start position: 446
# Neighboring characters: 446: 1 447: 0 448:  449: స 450: ం 451: వ 452: త 453: ్ 454: స 455: ర 456: ా 457: ల
# Context snippet: రియు 10 సంవత్సరాలలో అతని
# -----------------------------------------------
# -----------------------------------------------
# 34. ప్లైమౌత్ :
# Question: అజోర్స్ అధిక పీడన ప్రాంతం విస్తరించడం వల్ల ఇంగ్లాండ్లోని ఏ ప్రాంతం ప్రయోజనం పొందుతుంది?
# Answer: నైరుతి ఇంగ్లాండ్కు
# Start position: 67
# Neighboring characters: 67: న 68: ై 69: ర 70: ు 71: త 72: ి 73:  74: ఇ 75: ం 76: గ 77: ్ 78: ల
# Context snippet: పుడు నైరుతి ఇంగ్లాండ్కు అనుక
# -----------------------------------------------
# -----------------------------------------------
# 35. సాహసం. :
# Question: సెయింట్ పీటర్ ఎవరిని యూదులు అని పిలుస్తారు?
# Plausible Answer: మతపరమైన చిత్రాలను గౌరవించటానికి నిరాకరించిన క్రైస్తవులను
# Start position: 358
# Neighboring characters: 358: మ 359: త 360: ప 361: ర 362: మ 363: ై 364: న 365:  366: చ 367: ి 368: త 369: ్
# Context snippet: ీటర్ మతపరమైన చిత్రాలను గౌరవించటానికి నిరాకరించిన క్రైస్తవులను "యూద
# -----------------------------------------------
# 36. వార్సా ఒప్పందం (_ P) :
# Question: 1955లో జర్మనీ విదేశాంగ మంత్రిగా ఎవరు ఉన్నారు?
# Plausible Answer: హాల్వార్డ్ లాంగే
# Start position: 362
# Neighboring characters: 362: హ 363: ా 364: ల 365: ్ 366: వ 367: ా 368: ర 369: ్ 370: డ 371: ్ 372:  373: ల
# Context snippet: త్రి హాల్వార్డ్ లాంగే అభివ
# -----------------------------------------------
# 37. భౌతికవాదం :
# Question: తగ్గించే భౌతికవాదం దేనికి పర్యాయపదంగా లేదు?
# Plausible Answer: శాస్త్రీయ "భౌతికవాదం"
# Start position: 0
# Neighboring characters: 0: శ 1: ా 2: స 3: ్ 4: త 5: ్ 6: ర 7: ీ 8: య 9:  10: " 11: భ
# Context snippet: శాస్త్రీయ "భౌతికవాదం" తరచు
# -----------------------------------------------
# 38. క్రైస్తవుడు :
# Question: ఏ నగరంలో వారికి "పీటర్" అనే మారుపేరు పెట్టారు?
# Plausible Answer: ఆంటియోచ్
# Start position: 253
# Neighboring characters: 253: ఆ 254: ం 255: ట 256: ి 257: య 258: ో 259: చ 260: ్ 261:  262: న 263: గ 264: ర
# Context snippet: ్చిన ఆంటియోచ్ నగరం
# -----------------------------------------------
# 39. సోనీ _ మ్యూజిక్ _ ఎంటర్టైన్మెంట్ :
# Question: ఒక పిటిషన్పై పది లక్షలకు పైగా ప్రజలు ఎన్ని గంటల్లో సంతకం చేశారు?
# Plausible Answer: ఇరవై నాలుగు
# Start position: 184
# Neighboring characters: 184: ఇ 185: ర 186: వ 187: ై 188:  189: న 190: ా 191: ల 192: ు 193: గ 194: ు 195:
# Context snippet: ేవలం ఇరవై నాలుగు గంటల
# -----------------------------------------------
# 40. ఓక్లహోమా _ సిటీ :
# Question: నార్మన్ ప్రాంతీయ ఆసుపత్రిలో ఎంత మంది ఉద్యోగులు పనిచేస్తున్నారు?
# Answer: (2,800).
# Start position: 209
# Neighboring characters: 209: ( 210: 2 211: , 212: 8 213: 0 214: 0 215: ) 216: . 217:  218: 219: 220:
# Context snippet: ిటల్ (2,800).
# -----------------------------------------------
# -----------------------------------------------
# 41. వేటగాడు-సంగ్రాహక :
# Question: చైనాలోని జు/హోన్సీ మహిళలలో, మహిళలు దేనిని కనుగొనడానికి పురుషులకు సహాయం చేస్తారు?
# Plausible Answer: క్వారీని
# Start position: 659
# Neighboring characters: 659: క 660: ్ 661: వ 662: ా 663: ర 664: ీ 665: న 666: ి 667:  668: గ 669: ు 670: ర
# Context snippet: ిళలు క్వారీని గుర్
# -----------------------------------------------
# 42. ఐక్యరాజ్యసమితి _ జనాభా _ నిధి :
# Question: ఏ స్థానిక ప్రచారాలలో యుఎన్ఎఫ్పిఎ ఎక్కువగా పాల్గొంటుంది?
# Plausible Answer: ప్రసూతి ఫిస్టులా మరియు స్త్రీ జననేంద్రియ వైకల్యానికి వ్యతిరేకంగా
# Start position: 451
# Neighboring characters: 451: ప 452: ్ 453: ర 454: స 455: ూ 456: త 457: ి 458:  459: ఫ 460: ి 461: స 462: ్
# Context snippet: టీవల ప్రసూతి ఫిస్టులా మరియు స్త్రీ జననేంద్రియ వైకల్యానికి వ్యతిరేకంగా ప్రప
# -----------------------------------------------
# 43. రష్యన్ _ సోవియట్ _ ఫెడరేటివ్ _ సోషలిస్ట్ _ రిపబ్లిక్ :
# Question: ఏ తేదీన ఆర్. ఎస్. ఎఫ్. ఎస్. ఆర్. అధ్యక్ష పదవికి రెండవ ఎన్నికలు జరిగాయి?
# Plausible Answer: జూన్ 12న
# Start position: 108
# Neighboring characters: 108: జ 109: ూ 110: న 111: ్ 112:  113: 1 114: 2 115: న 116:  117: బ 118: ో 119: ర
# Context snippet: ారు. జూన్ 12న బోరి
# -----------------------------------------------
# 44. అలెగ్జాండర్ _ గ్రాహం _ బెల్ :
# Question: అనేక కోర్టు కేసుల వెనుక ఎలిషా గ్రే మరియు ఇంకెవరు ఉన్నారు?
# Answer: అమోస్ డాల్బియర్
# Start position: 579
# Neighboring characters: 579: అ 580: మ 581: ో 582: స 583: ్ 584:  585: డ 586: ా 587: ల 588: ్ 589: బ 590: ి
# Context snippet: రియు అమోస్ డాల్బియర్ సవాళ
# -----------------------------------------------
# -----------------------------------------------
# 45. పబ్ :
# Question: నాగలి భోజనం ఏ సంస్కృతి వంటకాల్లో భాగం?
# Answer: బ్రిటిష్ ఆహార
# Start position: 136
# Neighboring characters: 136: బ 137: ్ 138: ర 139: ి 140: ట 141: ి 142: ష 143: ్ 144:  145: ఆ 146: హ 147: ా
# Context snippet: నిలో బ్రిటిష్ ఆహార పదార
# -----------------------------------------------
# -----------------------------------------------
# 46. ఇంటర్నెట్ _ సర్వీస్ _ ప్రొవైడర్ :
# Question: WISPల కోసం ఎలాంటి అసాధారణ నెట్వర్కింగ్ ఉపయోగించబడుతుంది?
# Plausible Answer: వై-ఫై వైర్లెస్ మెష్ నెట్వర్కింగ్
# Start position: 152
# Neighboring characters: 152: వ 153: ై 154: - 155: ఫ 156: ై 157:  158: వ 159: ై 160: ర 161: ్ 162: ల 163: ె
# Context snippet: ధారణ వై-ఫై వైర్లెస్ మెష్ నెట్వర్కింగ్ లేదా
# -----------------------------------------------
# 47. కామిక్స్ :
# Question: బడ్ ఫిషర్ ఏ కామిక్ స్ట్రిప్ తో విఫలమయ్యాడు?
# Plausible Answer: మట్ మరియు జెఫ్
# Start position: 118
# Neighboring characters: 118: మ 119: ట 120: ్ 121:  122: మ 123: ర 124: ి 125: య 126: ు 127:  128: జ 129: ె
# Context snippet: ర్స్ మట్ మరియు జెఫ్ యొక్
# -----------------------------------------------
# 48. సెయింట్ _ హెలెనా :
# Question: ప్రజా సభ్యులకు మద్దతు ఎలా ఇవ్వబడింది?
# Answer: మానవ హక్కుల ప్రశ్నలతో
# Start position: 176
# Neighboring characters: 176: మ 177: ా 178: న 179: వ 180:  181: హ 182: క 183: ్ 184: క 185: ు 186: ల 187:
# Context snippet: చడం, మానవ హక్కుల ప్రశ్నలతో ప్రజ
# -----------------------------------------------
# -----------------------------------------------
# 49. ఆశాజనకమైన హల్లులు (_ c) :
# Question: ఆశించిన మరియు ఆశించని హల్లులతో పాటు/బి/దేనిని సూచిస్తుంది?
# Answer: బురద హల్లులు
# Start position: 257
# Neighboring characters: 257: బ 258: ు 259: ర 260: ద 261:  262: హ 263: ల 264: ్ 265: ల 266: ు 267: ల 268: ు
# Context snippet: భంలో బురద హల్లులు తక్క
# -----------------------------------------------
# -----------------------------------------------
# 50. హైడ్రోజన్ :
# Question: హైడ్రోజన్ వాయువు యొక్క రెండు రూపాలు ఏమిటి?
# Answer: (డైహైడ్రోజన్ లేదా మాలిక్యులర్ హైడ్రోజన్)
# Start position: 17
# Neighboring characters: 17: ( 18: డ 19: ై 20: హ 21: ై 22: డ 23: ్ 24: ర 25: ో 26: జ 27: న 28: ్
# Context snippet: యువు (డైహైడ్రోజన్ లేదా మాలిక్యులర్ హైడ్రోజన్) అత్య
# -----------------------------------------------
# -----------------------------------------------
# 51. స్పేస్ రేస్ (_ R) :
# Question: యుద్ధం తరువాత, సెర్గీ కొరోలెవ్ ఏ పేరుతో పిలువబడ్డాడు?
# Answer: USSR యొక్క ప్రధాన రాకెట్ మరియు అంతరిక్ష నౌక ఇంజనీర్
# Start position: 544
# Neighboring characters: 544: U 545: S 546: S 547: R 548:  549: య 550: ొ 551: క 552: ్ 553: క 554:  555: ప
# Context snippet: అతను USSR యొక్క ప్రధాన రాకెట్ మరియు అంతరిక్ష నౌక ఇంజనీర్ అయ్య
# -----------------------------------------------
# -----------------------------------------------
# 52. వెబ్ బ్రౌజర్ (_ b) :
# Question: డిఫాల్ట్ సెర్చ్ ఇంజిన్గా గూగుల్ ఏ ఇతర బ్రౌజర్ను కలిగి ఉంది?
# Answer: క్రోమ్
# Start position: 431
# Neighboring characters: 431: క 432: ్ 433: ర 434: ో 435: మ 436: ్ 437: ల 438: ో 439:  440: డ 441: ి 442: ఫ
# Context snippet: గుల్ క్రోమ్లో డి
# -----------------------------------------------
# -----------------------------------------------
# 53. బీడౌ _ నావిగేషన్ _ శాటిలైట్ _ సిస్టమ్ :
# Question: ఈ వ్యవస్థ కోసం ప్రయోగించిన మూడవ ఉపగ్రహం పేరు ఏమిటి?
# Answer: బీడౌ-1సి
# Start position: 124
# Neighboring characters: 124: బ 125: ీ 126: డ 127: ౌ 128: - 129: 1 130: స 131: ి 132:  133: ( 134: బ 135: ్
# Context snippet: రహం, బీడౌ-1సి (బ్య
# -----------------------------------------------
# -----------------------------------------------
# 54. కానన్ చట్టం (_ l) :
# Question: 1572లో ప్రెస్బిటేరియన్లు ఎవరికి ఫిర్యాదు చేశారు?
# Answer: పార్లమెంటుకు
# Start position: 50
# Neighboring characters: 50: ప 51: ా 52: ర 53: ్ 54: ల 55: మ 56: ె 57: ం 58: ట 59: ు 60: క 61: ు
# Context snippet: లోనే పార్లమెంటుకు హెచ్
# -----------------------------------------------
# -----------------------------------------------
# 55. కమ్యూనికేషన్స్ _ ఇన్ _ సోమాలియా :
# Question: వలసరాజ్యాల కాలం ఎప్పుడు ఉండేది?
# Plausible Answer: 1960
# Start position: 166
# Neighboring characters: 166: 1 167: 9 168: 6 169: 0 170:  171: ల 172: ో 173:  174: స 175: ్ 176: వ 177: ా
# Context snippet: ంది. 1960 లో స
# -----------------------------------------------
# 56. కాటలాన్ భాష (_ L) :
# Question: వ్యుత్పత్తులలో ఏ ఇతర పద మార్పులు సంభవించవచ్చు?
# Answer: ధ్వని ప్రత్యామ్నాయాలు
# Start position: 185
# Neighboring characters: 185: ధ 186: ్ 187: వ 188: న 189: ి 190:  191: ప 192: ్ 193: ర 194: త 195: ్ 196: య
# Context snippet: న్ని ధ్వని ప్రత్యామ్నాయాలు సంభవ
# -----------------------------------------------
# -----------------------------------------------
# 57. బోస్టన్ :
# Question: మొదటి సంవత్సరంలో హబ్ వే ఎన్ని రైడ్స్ నమోదు చేసింది?
# Answer: 140,000 కంటే ఎక్కువ రైడ్లను
# Start position: 548
# Neighboring characters: 548: 1 549: 4 550: 0 551: , 552: 0 553: 0 554: 0 555:  556: క 557: ం 558: ట 559: ే
# Context snippet: లోపు 140,000 కంటే ఎక్కువ రైడ్లను లాగి
# -----------------------------------------------
# -----------------------------------------------
# 58. యూనివర్సల్ స్టూడియోస్ (_ S) :
# Question: MAC ఏజెంట్ ఎవరు?
# Plausible Answer: లూ వాసెర్మాన్
# Start position: 359
# Neighboring characters: 359: ల 360: ూ 361:  362: వ 363: ా 364: స 365: ె 366: ర 367: ్ 368: మ 369: ా 370: న
# Context snippet: ెంట్ లూ వాసెర్మాన్ తన క
# -----------------------------------------------
# 59. ఎస్టోనియన్ భాష (_ L) :
# Question: ప్రచురించబడిన మొదటి ఎస్టోనియన్ భాషా పుస్తకం ఏది?
# Answer: లూథరన్ మాన్యుస్క్రిప్ట్,
# Start position: 195
# Neighboring characters: 195: ల 196: ూ 197: థ 198: ర 199: న 200: ్ 201:  202: మ 203: ా 204: న 205: ్ 206: య
# Context snippet: ్తకం లూథరన్ మాన్యుస్క్రిప్ట్, ఇది
# -----------------------------------------------
# -----------------------------------------------
# 60. కాగితం :
# Question: అంగుళాలలో అమర్చబడి, కాగితం మందం యొక్క సాధారణ పరిధి ఏమిటి?
# Answer: (0.0028 మరియు 0.0071) మందంగా
# Start position: 222
# Neighboring characters: 222: ( 223: 0 224: . 225: 0 226: 0 227: 2 228: 8 229:  230: మ 231: ర 232: ి 233: య
# Context snippet: టర్ల (0.0028 మరియు 0.0071) మందంగా ఉండవ
# -----------------------------------------------
# -----------------------------------------------
# 61. వయోజన _ సమకాలీన _ సంగీతం :
# Question: పాప్, సోల్, రిథమ్ అండ్ బ్లూస్, నిశ్శబ్ద తుఫాను మరియు రాక్లతో పాటు, ఏ సంగీత శైలి వయోజన సమకాలీనులను ప్రభావితం చేసింది?
# Answer: సులభంగా వినడం,
# Start position: 144
# Neighboring characters: 144: స 145: ు 146: ల 147: భ 148: ం 149: గ 150: ా 151:  152: వ 153: ి 154: న 155: డ
# Context snippet: ిలలో సులభంగా వినడం, పాప్
# -----------------------------------------------
# -----------------------------------------------
# 62. పగటి వెలుతురు పొదుపు సమయం (_ s) :
# Question: ఎండలో ఎక్కువ సమయం గడపడం వల్ల ఏ క్యాన్సర్ వస్తుంది?
# Answer: చర్మ క్యాన్సర్కు
# Start position: 370
# Neighboring characters: 370: చ 371: ర 372: ్ 373: మ 374:  375: క 376: ్ 377: య 378: ా 379: న 380: ్ 381: స
# Context snippet: ్గతం చర్మ క్యాన్సర్కు దారి
# -----------------------------------------------
# -----------------------------------------------
# 63. రాయల్ _ ఇన్స్టిట్యూట్ _ ఆఫ్ _ బ్రిటిష్ _ ఆర్కిటెక్ట్స్ :
# Question: ఆర్ఐబీఏ చార్టర్డ్ సభ్యులు తమ హోదాను సూచించడానికి వారి పేరు నుండి దేనిని తొలగించవచ్చు?
# Plausible Answer: ఆర్ఐబీఏ
# Start position: 155
# Neighboring characters: 155: ఆ 156: ర 157: ్ 158: ఐ 159: బ 160: ీ 161: ఏ 162: న 163: ు 164:  165: జ 166: ో
# Context snippet: ల్స్ ఆర్ఐబీఏను జో
# -----------------------------------------------
# 64. నేషనల్ _ ఆర్కైవ్స్ _ అండ్ _ రికార్డ్స్ _ అడ్మినిస్ట్రేషన్ :
# Question: ఫుట్నోట్ వెబ్సైట్ యొక్క ప్రధాన లక్ష్యం ఏమిటి?
# Plausible Answer: "దాని అసలు రికార్డులను సంరక్షించడానికి
# Start position: 369
# Neighboring characters: 369: " 370: ద 371: ా 372: న 373: ి 374:  375: అ 376: స 377: ల 378: ు 379:  380: ర
# Context snippet: రియు "దాని అసలు రికార్డులను సంరక్షించడానికి NARA
# -----------------------------------------------
# 65. ట్రిస్టాన్ _ డా _ కున్హా :
# Question: మైళ్ళలో, గంటకు 120 కిలోమీటర్లకు సమానం ఏమిటి?
# Plausible Answer: 190
# Start position: 30
# Neighboring characters: 30: 1 31: 9 32: 0 33:  34: క 35: ి 36: ల 37: ో 38: మ 39: ీ 40: ట 41: ర
# Context snippet: ంటకు 190 కిలో
# -----------------------------------------------
# 66. యూనివర్శిటీ _ ఆఫ్ _ కాన్సాస్ :
# Question: కెయు లోని వైద్య కేంద్రం యొక్క మూడు భాగాలు ఏమిటి?
# Answer: స్కూల్ ఆఫ్ మెడిసిన్, స్కూల్ ఆఫ్ నర్సింగ్ మరియు స్కూల్ ఆఫ్ హెల్త్ ప్రొఫెషన్స్.
# Start position: 65
# Neighboring characters: 65: స 66: ్ 67: క 68: ూ 69: ల 70: ్ 71:  72: ఆ 73: ఫ 74: ్ 75:  76: మ
# Context snippet: ాయిః స్కూల్ ఆఫ్ మెడిసిన్, స్కూల్ ఆఫ్ నర్సింగ్ మరియు స్కూల్ ఆఫ్ హెల్త్ ప్రొఫెషన్స్. ఇంకా
# -----------------------------------------------
# -----------------------------------------------
# 67. నాన్జింగ్ :
# Question: నాన్జింగ్ రాష్ట్ర రాజధానిగా ఎప్పుడు మారింది?
# Answer: క్రీ. శ. 229
# Start position: 99
# Neighboring characters: 99: క 100: ్ 101: ర 102: ీ 103: . 104:  105: శ 106: . 107:  108: 2 109: 2 110: 9
# Context snippet: పుడు క్రీ. శ. 229 లో న
# -----------------------------------------------
# -----------------------------------------------
# 68. అరేనా _ ఫుట్బాల్ _ లీగ్ :
# Question: సింగిల్-ఎంటిటీ మోడల్ కింద ఆటగాళ్ల హక్కులు ఎవరికి ఉన్నాయి?
# Answer: లీగ్
# Start position: 56
# Neighboring characters: 56: ల 57: ీ 58: గ 59: ్ 60:  61: జ 62: ట 63: ్ 64: ల 65: ు 66: , 67:
# Context snippet: ంది, లీగ్ జట్ల
# -----------------------------------------------
# -----------------------------------------------
# 69. మాండలికం :
# Question: క్యాంపిడనీస్ సార్డినియన్ ఏ భాష యొక్క రూపాంతరం?
# Answer: సార్డినియన్ భాష
# Start position: 0
# Neighboring characters: 0: స 1: ా 2: ర 3: ్ 4: డ 5: ి 6: న 7: ి 8: య 9: న 10: ్ 11:
# Context snippet: సార్డినియన్ భాష దాని
# -----------------------------------------------
# -----------------------------------------------
# 70. బెర్న్ :
# Question: బెర్న్ ఎక్కడ ఉంది?
# Answer: స్విట్జర్లాండ్
# Start position: 194
# Neighboring characters: 194: స 195: ్ 196: వ 197: ి 198: ట 199: ్ 200: జ 201: ర 202: ్ 203: ల 204: ా 205: ం
# Context snippet: rn]) స్విట్జర్లాండ్ యొక్
# -----------------------------------------------
# -----------------------------------------------
# 71. వెస్ట్ మినిస్టర్ _ అబ్బే :
# Question: చాప్టర్ హౌస్లో మరెవరు కలుసుకోలేదు?
# Plausible Answer: కింగ్స్ గ్రేట్ కౌన్సిల్ మరియు కామన్స్
# Start position: 435
# Neighboring characters: 435: క 436: ి 437: ం 438: గ 439: ్ 440: స 441: ్ 442:  443: గ 444: ్ 445: ర 446: ే
# Context snippet: ులైన కింగ్స్ గ్రేట్ కౌన్సిల్ మరియు కామన్స్ సమావ
# -----------------------------------------------
# 72. రాజకీయ _ అవినీతి :
# Question: కరువు పరిస్థితులను ఏది ప్రేరేపించగలదు?
# Answer: కరువు
# Start position: 97
# Neighboring characters: 97: క 98: ర 99: ు 100: వ 101: ు 102:  103: మ 104: ర 105: ి 106: య 107: ు 108:
# Context snippet: ారు. కరువు మరియ
# -----------------------------------------------
# -----------------------------------------------
# 73. శాస్త్రీయ సంగీతం (_ m) :
# Question: నైట్ ఆన్ బాల్డ్ మౌంటైన్ ఎవరు రాశారు?
# Answer: ముసోర్గ్స్కీ
# Start position: 300
# Neighboring characters: 300: మ 301: ు 302: స 303: ో 304: ర 305: ్ 306: గ 307: ్ 308: స 309: ్ 310: క 311: ీ
# Context snippet: ్స్, ముసోర్గ్స్కీ యొక్
# -----------------------------------------------
# -----------------------------------------------
# 74. స్లావ్స్ :
# Question: నాజీ ఆకలి ప్రణాళిక మరియు జనరల్ ప్లాన్ ఓస్ట్ ఫలితంగా ఎంత మంది మరణించారు మరియు ఖైదు చేయబడ్డారు?
# Answer: 19.3 మిలియన్ల మంది పౌరులు మరియు
# Start position: 405
# Neighboring characters: 405: 1 406: 9 407: . 408: 3 409:  410: మ 411: ి 412: ల 413: ి 414: య 415: న 416: ్
# Context snippet: తంగా 19.3 మిలియన్ల మంది పౌరులు మరియు యుద్
# -----------------------------------------------
# -----------------------------------------------
# 75. సౌతాంప్టన్ :
# Question: కొత్త కౌంటీ కౌన్సిల్ సౌతాంప్టన్ పాలనను ఏ సంస్థతో పంచుకుంది?
# Answer: సౌతాంప్టన్లోని కార్పొరేషన్
# Start position: 202
# Neighboring characters: 202: స 203: ౌ 204: త 205: ా 206: ం 207: ప 208: ్ 209: ట 210: న 211: ్ 212: ల 213: ో
# Context snippet: పుడు సౌతాంప్టన్లోని కార్పొరేషన్ మరియ
# -----------------------------------------------
# -----------------------------------------------
# 76. ఒప్పందం :
# Question: అధ్యక్ష డిక్రీ ద్వారా ఒక ఒప్పందాన్ని దేశీయ చట్టంలో చేర్చాలని ఏ బ్రెజిలియన్ సంస్థ తీర్పు ఇచ్చింది?
# Answer: ఫెడరల్ సుప్రీంకోర్టు
# Start position: 595
# Neighboring characters: 595: ఫ 596: ె 597: డ 598: ర 599: ల 600: ్ 601:  602: స 603: ు 604: ప 605: ్ 606: ర
# Context snippet: ాలని ఫెడరల్ సుప్రీంకోర్టు తీర్
# -----------------------------------------------
# -----------------------------------------------
# 77. జోసిప్ _ బ్రోజ్ _ టిటో :
# Question: బ్రోజ్ ఎంతకాలం ఆసుపత్రిలో ఉన్నాడు?
# Answer: 13 నెలల
# Start position: 11
# Neighboring characters: 11: 1 12: 3 13:  14: న 15: ె 16: ల 17: ల 18:  19: త 20: ర 21: ు 22: వ
# Context snippet: రిలో 13 నెలల తరువ
# -----------------------------------------------
# -----------------------------------------------
# 78. మార్షల్ దీవులు (_ I) :
# Question: 1788లో మార్షల్ దీవులకు ఎవరు వచ్చారు?
# Answer: కెప్టెన్ జాన్ చార్లెస్ మార్షల్ మరియు థామస్ గిల్బర్ట్
# Start position: 0
# Neighboring characters: 0: క 1: ె 2: ప 3: ్ 4: ట 5: ె 6: న 7: ్ 8:  9: జ 10: ా 11: న
# Context snippet: కెప్టెన్ జాన్ చార్లెస్ మార్షల్ మరియు థామస్ గిల్బర్ట్ 1788
# -----------------------------------------------
# -----------------------------------------------
# 79. స్జ్లాచ్టా :
# Question: ఇది కాథలిక్కుల పట్ల సాంస్కృతిక ఒత్తిడిని బాగా తగ్గించింది.
# Answer: యూనియన్ ఆఫ్ బ్రెస్ట్
# Start position: 166
# Neighboring characters: 166: య 167: ూ 168: న 169: ి 170: య 171: న 172: ్ 173:  174: ఆ 175: ఫ 176: ్ 177:
# Context snippet: 96లో యూనియన్ ఆఫ్ బ్రెస్ట్ ద్వా
# -----------------------------------------------
# -----------------------------------------------
# 80. వర్జిల్ :
# Question: విర్జిలియస్ కాకుండా, ఆధునిక వాడుకలో ఏ ఇతర స్పెల్లింగ్ అనుమతించబడింది?
# Answer: వెర్జిలియస్
# Start position: 36
# Neighboring characters: 36: వ 37: ె 38: ర 39: ్ 40: జ 41: ి 42: ల 43: ి 44: య 45: స 46: ్ 47:
# Context snippet: ాలలో వెర్జిలియస్ ను వ
# -----------------------------------------------
# -----------------------------------------------
# 81. ఆల్ప్స్ :
# Question: ఆల్ప్స్ లో చాలా పాస్లు ఎప్పుడు మూసివేయబడతాయి?
# Answer: శీతాకాలంలో
# Start position: 247
# Neighboring characters: 247: శ 248: ీ 249: త 250: ా 251: క 252: ా 253: ల 254: ం 255: ల 256: ో 257:  258: చ
# Context snippet: ాయి. శీతాకాలంలో చాలా
# -----------------------------------------------
# -----------------------------------------------
# 82. జీన్ :
# Question: 1905లో'జన్యుశాస్త్రం'అనే పదాన్ని మొదటిసారిగా ఎవరు ఉపయోగించారు?
# Answer: విలియం బేటిసన్
# Start position: 304
# Neighboring characters: 304: వ 305: ి 306: ల 307: ి 308: య 309: ం 310:  311: బ 312: ే 313: ట 314: ి 315: స
# Context snippet: 05లో విలియం బేటిసన్ ఉపయో
# -----------------------------------------------
# -----------------------------------------------
# 83. గినియా-బిసావు :
# Question: గుంబేను ఏ ఇతర దేశాల నుండి దూరంగా ఉంచారు?
# Answer: సాధారణంగా సమన్వయవాద ఆఫ్రికన్ దేశాలలో
# Start position: 228
# Neighboring characters: 228: స 229: ా 230: ధ 231: ా 232: ర 233: ణ 234: ం 235: గ 236: ా 237:  238: స 239: మ
# Context snippet: ికి, సాధారణంగా సమన్వయవాద ఆఫ్రికన్ దేశాలలో కూడా
# -----------------------------------------------
# -----------------------------------------------
# 84. జాబితా _ ఆఫ్ _ నంబర్డ్ _ స్ట్రీట్స్ _ ఇన్ _ మన్హట్టన్ :
# Question: తూర్పు 2 వ వీధికి ప్రారంభ స్థానం ఏ అవెన్యూ?
# Answer: సి
# Start position: 56
# Neighboring characters: 56: స 57: ి 58:  59: వ 60: ద 61: ్ 62: ద 63:  64: ప 65: ్ 66: ర 67: ా
# Context snippet: న్యూ సి వద్ద
# -----------------------------------------------
# -----------------------------------------------
# 85. మెదడు. :
# Question: అభివృద్ధి సమయంలో ముందరి మెదడును ఏమిటి అంటారు?
# Answer: ప్రోసెన్స్ఫాలన్,
# Start position: 273
# Neighboring characters: 273: ప 274: ్ 275: ర 276: ో 277: స 278: ె 279: న 280: ్ 281: స 282: ్ 283: ఫ 284: ా
# Context snippet: ుసగా ప్రోసెన్స్ఫాలన్, మెసె
# -----------------------------------------------
# -----------------------------------------------
# 86. తూర్పు సమీపంలో (_ E) :
# Question: దక్షిణ, మధ్య మధ్యధరా తీరాలలో చాలా వరకు అడుగు పెట్టడానికి ఏమి అవసరమైంది?
# Answer: ఒట్టోమన్ సామ్రాజ్యం నుండి అనుమతి
# Start position: 497
# Neighboring characters: 497: ఒ 498: ట 499: ్ 500: ట 501: ో 502: మ 503: న 504: ్ 505:  506: స 507: ా 508: మ
# Context snippet: ేది. ఒట్టోమన్ సామ్రాజ్యం నుండి అనుమతి లేకు
# -----------------------------------------------
# -----------------------------------------------
# 87. జెజియాంగ్ :
# Question: 1955-1977 నుండి ఏమి జరిగింది?
# Plausible Answer: సాంస్కృతిక విప్లవం
# Start position: 333
# Neighboring characters: 333: స 334: ా 335: ం 336: స 337: ్ 338: క 339: ృ 340: త 341: ి 342: క 343:  344: వ
# Context snippet: ంది. సాంస్కృతిక విప్లవం (196
# -----------------------------------------------
# 88. రక్షణ మంత్రిత్వ శాఖ (యునైటెడ్ కింగ్డమ్) :
# Question: బ్రిటిష్ సాయుధ దళాలు ఏ సంవత్సరంలో సృష్టించబడ్డాయి?
# Plausible Answer: 1998
# Start position: 0
# Neighboring characters: 0: 1 1: 9 2: 9 3: 8 4:  5: స 6: ్ 7: ట 8: ్ 9: ర 10: ా 11: ట
# Context snippet: 1998 స్ట్
# -----------------------------------------------
# 89. హై-డెఫినిషన్ _ టెలివిజన్ :
# Question: 2008లో ఏ కంప్రెస్ చేయని నిల్వ ఎంపిక ప్రవేశపెట్టబడింది?
# Answer: హౌపాగ్ 1212 పర్సనల్ వీడియో రికార్డర్
# Start position: 158
# Neighboring characters: 158: హ 159: ౌ 160: ప 161: ా 162: గ 163: ్ 164:  165: 1 166: 2 167: 1 168: 2 169:
# Context snippet: 8లో, హౌపాగ్ 1212 పర్సనల్ వీడియో రికార్డర్ ప్రవ
# -----------------------------------------------
# -----------------------------------------------
# 90. చెక్క. :
# Question: రింగ్-పోరస్ గట్టి చెక్కలు వాటి లక్షణాలకు మరియు ఏ ఇతర కారకాలకు మధ్య స్పష్టమైన సంబంధాన్ని కలిగి ఉంటాయి?
# Answer: పెరుగుదల రేటు
# Start position: 36
# Neighboring characters: 36: ప 37: ె 38: ర 39: ు 40: గ 41: ు 42: ద 43: ల 44:  45: ర 46: ే 47: ట
# Context snippet:  కలప పెరుగుదల రేటు మరియ
# -----------------------------------------------
# -----------------------------------------------
# 91. సోమాలీలు :
# Question: సోమాలియాలోని ఏ భౌగోళిక భాగంలో ముఖ్యమైన పాలియోలిథిక్ రాతి పనిముట్లు కనుగొనబడ్డాయి?
# Answer: ఉత్తర
# Start position: 131
# Neighboring characters: 131: ఉ 132: త 133: ్ 134: త 135: ర 136:  137: స 138: ో 139: మ 140: ా 141: ల 142: ి
# Context snippet: ాయి. ఉత్తర సోమా
# -----------------------------------------------
# -----------------------------------------------
# 92. మధ్య యుగాలు (_ A) :
# Question: బైబిల్ చదవాలని విక్లిఫ్ఫ్ ఎవరు నమ్మాడు?
# Answer: సామాన్యులకు
# Start position: 183
# Neighboring characters: 183: స 184: ా 185: మ 186: ా 187: న 188: ్ 189: య 190: ు 191: ల 192: క 193: ు 194:
# Context snippet: ాడు, సామాన్యులకు బైబి
# -----------------------------------------------
# -----------------------------------------------
# 93. ఫోనాలజీ :
# Question: ది సౌండ్ ప్యాటర్న్ ఆఫ్ ఇంగ్లీష్ ఎప్పుడు ప్రచురించబడింది?
# Answer: 1968లో
# Start position: 0
# Neighboring characters: 0: 1 1: 9 2: 6 3: 8 4: ల 5: ో 6:  7: న 8: ో 9: మ 10: ్ 11:
# Context snippet: 1968లో నోమ్
# -----------------------------------------------
# -----------------------------------------------
# 94. కంప్యూటర్ :
# Question: ఏ రకమైన కంప్యూటర్ ఎన్క్రిప్షన్ అల్గారిథమ్లను త్వరగా విచ్ఛిన్నం చేయగలదు?
# Answer: క్వాంటం కంప్యూటర్లు
# Start position: 461
# Neighboring characters: 461: క 462: ్ 463: వ 464: ా 465: ం 466: ట 467: ం 468:  469: క 470: ం 471: ప 472: ్
# Context snippet: రణకు క్వాంటం కంప్యూటర్లు కొన్
# -----------------------------------------------
# -----------------------------------------------
# 95. నల్ల ప్రజలు (_ p) :
# Question: ఈ సంఘాలు ఎప్పుడు ప్రారంభమయ్యాయి?
# Answer: కొన్ని చరిత్రపూర్వ సమాజాలకు చెందినవి.
# Start position: 66
# Neighboring characters: 66: క 67: ొ 68: న 69: ్ 70: న 71: ి 72:  73: చ 74: ర 75: ి 76: త 77: ్
# Context snippet: టిలో కొన్ని చరిత్రపూర్వ సమాజాలకు చెందినవి. మరిక
# -----------------------------------------------
# -----------------------------------------------
# 96. ది టైమ్స్ (_ T) :
# Question: 1930లలో జర్మన్ బుజ్జగింపును అభ్యసించే ఏ ప్రముఖ ప్రభుత్వ అధికారితో టైమ్స్ పొత్తు పెట్టుకుంది?
# Answer: నెవిల్లే చాంబర్లైన్.
# Start position: 300
# Neighboring characters: 300: న 301: ె 302: వ 303: ి 304: ల 305: ్ 306: ల 307: ే 308:  309: చ 310: ా 311: ం
# Context snippet: యంగా నెవిల్లే చాంబర్లైన్.
# -----------------------------------------------
# -----------------------------------------------
# 97. న్యూ ఢిల్లీ (_ D) :
# Question: భారతదేశం ఏ సంవత్సరంలో స్వాతంత్ర్యం పొందింది?
# Answer: 1947లో
# Start position: 0
# Neighboring characters: 0: 1 1: 9 2: 4 3: 7 4: ల 5: ో 6:  7: భ 8: ా 9: ర 10: త 11: ద
# Context snippet: 1947లో భారత
# -----------------------------------------------
# -----------------------------------------------
# 98. పక్షి వలస (_ m) :
# Question: స్ప్రింగ్ ఓవర్షూట్కు ప్రసిద్ధి చెందిన మరో ప్రదేశం ఏది?
# Answer: మరియు ఇంగ్లాండ్లోని స్పర్న్.
# Start position: 389
# Neighboring characters: 389: మ 390: ర 391: ి 392: య 393: ు 394:  395: ఇ 396: ం 397: గ 398: ్ 399: ల 400: ా
# Context snippet: ర్క్ మరియు ఇంగ్లాండ్లోని స్పర్న్.
# -----------------------------------------------
# -----------------------------------------------
# 99. అట్లాంటిక్ _ సిటీ, _ న్యూ _ జెర్సీ :
# Question: ఉప్పునీటి టాఫీని ఏ సంవత్సరంలో రూపొందించారు?
# Answer: 1883లో,
# Start position: 0
# Neighboring characters: 0: 1 1: 8 2: 8 3: 3 4: ల 5: ో 6: , 7:  8: డ 9: ే 10: వ 11: ి
# Context snippet: 1883లో, డేవి
# -----------------------------------------------
# -----------------------------------------------
# 100. ఇమ్యునాలజీ :
# Question: ఏ రకమైన కణాలు ఎయిడ్స్ ద్వారా అణచివేయబడతాయి?
# Answer: సిడి4 + ("హెల్పర్") టి కణాలు, డెండ్రిటిక్ కణాలు మరియు మాక్రోఫేజ్లను
# Start position: 123
# Neighboring characters: 123: స 124: ి 125: డ 126: ి 127: 4 128:  129: + 130:  131: ( 132: " 133: హ 134: ె
# Context snippet: వారా సిడి4 + ("హెల్పర్") టి కణాలు, డెండ్రిటిక్ కణాలు మరియు మాక్రోఫేజ్లను అణచి
# -----------------------------------------------
# -----------------------------------------------
# 101. MP3 :
# Question: బ్రాండెన్బర్గ్ ఫ్రాన్హోఫెన్ ఇన్స్టిట్యూట్లో ఎప్పుడు చేరారు?
# Answer: 1993లో
# Start position: 742
# Neighboring characters: 742: 1 743: 9 744: 9 745: 3 746: ల 747: ో 748:  749: ఫ 750: ్ 751: ర 752: ా 753: న
# Context snippet: అతను 1993లో ఫ్రా
# -----------------------------------------------
# -----------------------------------------------
# 102. హౌస్ సంగీతం (_ m) :
# Question: మెల్ మరియు కిమ్ కోసం ఏ సమూహం యొక్క నిర్మాణాలు యూరోపాప్ ధ్వనికి ఇంటి అంశాలను జోడించాయి?
# Answer: స్టాక్ ఐట్కెన్ వాటర్మాన్ యొక్క
# Start position: 317
# Neighboring characters: 317: స 318: ్ 319: ట 320: ా 321: క 322: ్ 323:  324: ఐ 325: ట 326: ్ 327: క 328: ె
# Context snippet: కోసం స్టాక్ ఐట్కెన్ వాటర్మాన్ యొక్క నిర్
# -----------------------------------------------
# -----------------------------------------------
# 103. లెటర్ కేస్ (_ c) :
# Question: రెండు వేర్వేరు కేసులను ఉపయోగించిన స్క్రిప్ట్లను ఏమని పిలుస్తారు?
# Answer: ద్విసభగా
# Start position: 528
# Neighboring characters: 528: ద 529: ్ 530: వ 531: ి 532: స 533: భ 534: గ 535: ా 536:  537: ఉ 538: ం 539: డ
# Context snippet: తంలో ద్విసభగా ఉండే
# -----------------------------------------------
# -----------------------------------------------
# 104. చివావా _ (రాష్ట్రం) :
# Question: చివావాన్ ఎడారి ఏ పొరుగు మెక్సికన్ రాష్ట్రంలోకి కూడా విస్తరించి ఉంది?
# Answer: కోవాహులా
# Start position: 124
# Neighboring characters: 124: క 125: ో 126: వ 127: ా 128: హ 129: ు 130: ల 131: ా 132:  133: మ 134: ర 135: ి
# Context snippet: రమైన కోవాహులా మరియ
# -----------------------------------------------
# -----------------------------------------------
# 105. ఇమామా (షియా సిద్ధాంతం) :
# Question: షియా మతంలో వివిధ వర్గాలు ఎందుకు వచ్చాయి?
# Answer: వారు తమ ఇమామ్ల వారసత్వాలపై విభేదించారు,
# Start position: 69
# Neighboring characters: 69: వ 70: ా 71: ర 72: ు 73:  74: త 75: మ 76:  77: ఇ 78: మ 79: ా 80: మ
# Context snippet: కంటే వారు తమ ఇమామ్ల వారసత్వాలపై విభేదించారు, ముహమ
# -----------------------------------------------
# -----------------------------------------------
# 106. పిచ్ (సంగీతం) :
# Question: ధ్వని గురించి ప్రతి వ్యక్తి అవగాహనను? అని పిలుస్తారు.
# Answer: పిచ్
# Start position: 301
# Neighboring characters: 301: ప 302: ి 303: చ 304: ్ 305:  306: అ 307: న 308: ే 309: ద 310: ి 311:  312: ధ
# Context snippet: ్చు. పిచ్ అనేద
# -----------------------------------------------
# -----------------------------------------------
# 107. ఇంగ్లాండ్ _ జాతీయ _ ఫుట్బాల్ _ జట్టు :
# Question: బిబిసి రేడియో 5 లైవ్ ఏ సంవత్సరంలో ఇంగ్లాండ్ మ్యాచ్లను ప్రసారం చేయడం ప్రారంభించింది?
# Plausible Answer: 2010
# Start position: 333
# Neighboring characters: 333: 2 334: 0 335: 1 336: 0 337:  338: ప 339: ్ 340: ర 341: ప 342: ం 343: చ 344:
# Context snippet: హా). 2010 ప్రప
# -----------------------------------------------
# 108. హ్యూస్టన్ :
# Question: హ్యూస్టన్లో సాధారణంగా సంవత్సరానికి ఎంత వర్షం పడుతుంది?
# Answer: 49.8 in
# Start position: 790
# Neighboring characters: 790: 4 791: 9 792: . 793: 8 794:  795: i 796: n 797:  798: ( 799: − 800: 2 801: ,
# Context snippet: గటున 49.8 in (−2,
# -----------------------------------------------
# -----------------------------------------------
# 109. రాగి. :
# Question: బయోస్టాటిక్ లక్షణం లేనందున రాగిని సాధారణంగా ఎక్కడ ఉపయోగిస్తారు?
# Plausible Answer: నౌకల
# Start position: 126
# Neighboring characters: 126: న 127: ౌ 128: క 129: ల 130:  131: భ 132: ా 133: గ 134: ా 135: ల 136: న 137: ు
# Context snippet: నికి నౌకల భాగా
# -----------------------------------------------
# 110. గుర్తింపు _ (సామాజిక _ శాస్త్రం) :
# Question: చాలా మంది ప్రజలు తమ గుర్తింపు సమూహాల నుండి ఏమి పొందుతారు?
# Answer: సానుకూల ఆత్మగౌరవం యొక్క భావాన్ని
# Start position: 43
# Neighboring characters: 43: స 44: ా 45: న 46: ు 47: క 48: ూ 49: ల 50:  51: ఆ 52: త 53: ్ 54: మ
# Context snippet: ుండి సానుకూల ఆత్మగౌరవం యొక్క భావాన్ని పొంద
# -----------------------------------------------
# -----------------------------------------------
# 111. హిమాచల్ _ ప్రదేశ్ :
# Question: హిమాచల్ ప్రదేశ్ చీఫ్ కమిషనర్ల ప్రావిన్స్ ఎప్పుడు ఉనికిలోకి వచ్చింది?
# Answer: 1948 ఏప్రిల్ 15న
# Start position: 161
# Neighboring characters: 161: 1 162: 9 163: 4 164: 8 165:  166: ఏ 167: ప 168: ్ 169: ర 170: ి 171: ల 172: ్
# Context snippet: తంగా 1948 ఏప్రిల్ 15న హిమా
# -----------------------------------------------
# -----------------------------------------------
# 112. కమ్యూనికేషన్ :
# Question: మొక్కల ఆకులు మట్టిలో దేనితో కమ్యూనికేట్ చేస్తాయి?
# Plausible Answer: రైజోమ్ బ్యాక్టీరియా, శిలీంధ్రాలు మరియు కీటకాలతో
# Start position: 210
# Neighboring characters: 210: ర 211: ై 212: జ 213: ో 214: మ 215: ్ 216:  217: బ 218: ్ 219: య 220: ా 221: క
# Context snippet: లోని రైజోమ్ బ్యాక్టీరియా, శిలీంధ్రాలు మరియు కీటకాలతో కమ్య
# -----------------------------------------------
# 113. ద్రాక్ష. :
# Question: మద్యం తాగడం వల్ల కలిగే ఆరోగ్య ప్రయోజనాలు ఏమిటి?
# Answer: వాసోడిలేషన్
# Start position: 399
# Neighboring characters: 399: వ 400: ా 401: స 402: ో 403: డ 404: ి 405: ల 406: ే 407: ష 408: న 409: ్ 410:
# Context snippet: రియు వాసోడిలేషన్ తగ్గ
# -----------------------------------------------
# -----------------------------------------------
# 114. కంప్యూటర్ భద్రత (_ S) :
# Question: ఏ మౌలిక సదుపాయాలు దాడికి అతి తక్కువగా గురవుతాయి?
# Plausible Answer: చేస్తాయి. శక్తి, కమ్యూనికేషన్లు మరియు ఇతర సమాచారం వంటి క్లిష్టమైన వ్యవస్థలను
# Start position: 213
# Neighboring characters: 213: చ 214: ే 215: స 216: ్ 217: త 218: ా 219: య 220: ి 221: . 222:  223: శ 224: క
# Context snippet: ్గతం చేస్తాయి. శక్తి, కమ్యూనికేషన్లు మరియు ఇతర సమాచారం వంటి క్లిష్టమైన వ్యవస్థలను నియం
# -----------------------------------------------
# 115. ఆర్థడాక్స్ _ జుడాయిజం :
# Question: హలఖా గురించి ఆర్థడాక్స్ జుడాయిజంలో ఏ సమూహాలు గణనీయమైన ఏకాభిప్రాయాన్ని కలిగి ఉన్నాయి?
# Plausible Answer: హరేడి జుడాయిజం మరియు ఆధునిక ఆర్థడాక్స్ జుడాయిజం
# Start position: 41
# Neighboring characters: 41: హ 42: ర 43: ే 44: డ 45: ి 46:  47: జ 48: ు 49: డ 50: ా 51: య 52: ి
# Context snippet: యంగా హరేడి జుడాయిజం మరియు ఆధునిక ఆర్థడాక్స్ జుడాయిజం మధ్య
# -----------------------------------------------
# 116. జంతువు. :
# Question: అంతర్గత గదిలో ఆహారాన్ని జీర్ణం చేసే జీవులను ఏమని పిలుస్తారు?
# Answer: హెటెరోట్రోఫిక్,
# Start position: 191
# Neighboring characters: 191: హ 192: ె 193: ట 194: ె 195: ర 196: ో 197: ట 198: ్ 199: ర 200: ో 201: ఫ 202: ి
# Context snippet:  అవి హెటెరోట్రోఫిక్, సాధా
# -----------------------------------------------
# -----------------------------------------------
# 117. బీర్. :
# Question: 2001లో ఏ ప్రధాన క్రీడా కార్యక్రమం జరిగింది?
# Plausible Answer: ఫిఫా ప్రపంచ కప్
# Start position: 217
# Neighboring characters: 217: ఫ 218: ి 219: ఫ 220: ా 221:  222: ప 223: ్ 224: ర 225: ప 226: ం 227: చ 228:
# Context snippet: 2010 ఫిఫా ప్రపంచ కప్ కోసం
# -----------------------------------------------
# 118. జాతి _ మరియు _ జాతి _ లో _ యునైటెడ్ _ స్టేట్స్ _ జనాభా గణన :
# Question: 1850 కి ముందు యు. ఎస్. జనాభా గణనలో స్వేచ్ఛాయుత వ్యక్తులు ఎలా జాబితా చేయబడ్డారు?
# Answer: ఇంటి అధిపతికి బదులుగా
# Start position: 101
# Neighboring characters: 101: ఇ 102: ం 103: ట 104: ి 105:  106: అ 107: ధ 108: ి 109: ప 110: త 111: ి 112: క
# Context snippet: ిగా, ఇంటి అధిపతికి బదులుగా స్వత
# -----------------------------------------------
# -----------------------------------------------
# 119. యునైటెడ్ _ స్టేట్స్ _ డాలర్ :
# Question: కొంతమంది విరక్తులు దేనిని కొనుగోలు చేయడానికి మోసగించబడ్డారు?
# Plausible Answer: "తలక్రిందులుగా అక్షరాల లోపం" నాణేలను
# Start position: 607
# Neighboring characters: 607: " 608: త 609: ల 610: క 611: ్ 612: ర 613: ి 614: ం 615: ద 616: ు 617: ల 618: ు
# Context snippet: ట్లో "తలక్రిందులుగా అక్షరాల లోపం" నాణేలను కొను
# -----------------------------------------------
# 120. ఇంపీరియల్ _ కాలేజ్ _ లండన్ :
# Question: ఏ సంవత్సరంలో ఇంపీరియల్ సెయింట్ మేరీస్ హాస్పిటల్ మెడికల్ స్కూల్లో విలీనం అయ్యింది?
# Answer: 1988లో
# Start position: 0
# Neighboring characters: 0: 1 1: 9 2: 8 3: 8 4: ల 5: ో 6:  7: ఇ 8: ం 9: ప 10: ీ 11: ర
# Context snippet: 1988లో ఇంపీ
# -----------------------------------------------
# -----------------------------------------------
# 121. హనోవర్ :
# Question: గెహ్రీ టవర్ను నిర్మించిన ఆస్ట్రియన్ వాస్తుశిల్పి ఎవరు?
# Plausible Answer: ఫ్రాంక్ ఓ. గెహ్రీ
# Start position: 329
# Neighboring characters: 329: ఫ 330: ్ 331: ర 332: ా 333: ం 334: క 335: ్ 336:  337: ఓ 338: . 339:  340: గ
# Context snippet: క్ట్ ఫ్రాంక్ ఓ. గెహ్రీ రూపొ
# -----------------------------------------------
# 122. భావోద్వేగం. :
# Question: వీస్ మరియు క్రోపాన్జానో వారి రచనలను ఎప్పుడు ప్రచురించారు?
# Answer: (1996)
# Start position: 49
# Neighboring characters: 49: ( 50: 1 51: 9 52: 9 53: 6 54: ) 55:  56: చ 57: ే 58:  59: అ 60: భ
# Context snippet: జానో (1996) చే అ
# -----------------------------------------------
# -----------------------------------------------
# 123. Everton_F.C. :
# Question: ఎవర్టన్ ఏ సీజన్లో వారి నాలుగో లీగ్ టైటిల్ను గెలుచుకుంది?
# Answer: 1931-32
# Start position: 191
# Neighboring characters: 191: 1 192: 9 193: 3 194: 1 195: - 196: 3 197: 2 198:  199: ల 200: ో 201:  202: అ
# Context snippet: ంది. 1931-32 లో అ
# -----------------------------------------------
# -----------------------------------------------
# 124. పాత ఆంగ్లం (_ I) :
# Question: థేమ్స్ నదికి దక్షిణాన మరియు హంబర్ నదికి ఉత్తరాన ఏ ప్రాంతం ఉంది?
# Plausible Answer: నార్తంబ్రియన్
# Start position: 181
# Neighboring characters: 181: న 182: ా 183: ర 184: ్ 185: త 186: ం 187: బ 188: ్ 189: ర 190: ి 191: య 192: న
# Context snippet: రంగా నార్తంబ్రియన్ ప్రా
# -----------------------------------------------
# 125. విమాన వాహక నౌక (_ c) :
# Question: V/STOL దేనిని సూచించదు?
# Plausible Answer: విమానాలు నిలువుగా లేదా చిన్న టేకాఫ్ మరియు ల్యాండింగ్ (V/STOL) సామర్థ్యం కలిగి
# Start position: 465
# Neighboring characters: 465: వ 466: ి 467: మ 468: ా 469: న 470: ా 471: ల 472: ు 473:  474: న 475: ి 476: ల
# Context snippet: రియు విమానాలు నిలువుగా లేదా చిన్న టేకాఫ్ మరియు ల్యాండింగ్ (V/STOL) సామర్థ్యం కలిగి ఉంటా
# -----------------------------------------------
# 126. ఫెడరల్ _ ఏవియేషన్ _ అడ్మినిస్ట్రేషన్ :
# ...
# Context snippet: న్లు 1485లో పోర్
# -----------------------------------------------
# -----------------------------------------------
# 403. రష్యన్ భాష (_ L) :
# Question: వ్యావహారిక ప్రసంగాన్ని లాంఛనప్రాయంగా చేయడానికి ఎవరు బాధ్యత వహించారు?
# Plausible Answer: సోవియట్ ప్రభుత్వం
# Start position: 229
# Neighboring characters: 229: స 230: ో 231: వ 232: ి 233: య 234: ట 235: ్ 236:  237: ప 238: ్ 239: ర 240: భ
# Context snippet: ికి, సోవియట్ ప్రభుత్వం స్థా
# -----------------------------------------------
# 404. యునైటెడ్ _ స్టేట్స్ _ ఎయిర్ _ ఫోర్స్ :
# Question: యు. ఎస్. ఎ. ఎఫ్. కి ఓటిఎస్ ఎన్ని కమీషనింగ్ ప్రోగ్రామ్లను అందిస్తుంది?
# Answer: రెండు
# Start position: 420
# Neighboring characters: 420: ర 421: ె 422: ం 423: డ 424: ు 425:  426: వ 427: ే 428: ర 429: ్ 430: వ 431: ే
# Context snippet: OTS, రెండు వేర్
# -----------------------------------------------
# -----------------------------------------------
# 405. లైట్-ఎమిటింగ్ డయోడ్ (_ D) :
# Question: ఎలెక్ట్రోలుమినిసెన్స్ ప్రక్రియలో కొంత శక్తి వేడి మరియు కాంతిగా ఎందుకు విడుదల అవుతుంది?
# Answer: ఎలక్ట్రాన్లు మరియు కాంతి రంధ్రాల నుండి తిరిగి
# Start position: 704
# Neighboring characters: 704: ఎ 705: ల 706: క 707: ్ 708: ట 709: ్ 710: ర 711: ా 712: న 713: ్ 714: ల 715: ు
# Context snippet: న్ని ఎలక్ట్రాన్లు మరియు కాంతి రంధ్రాల నుండి తిరిగి కలపడ
# -----------------------------------------------
# -----------------------------------------------
# 406. గొప్ప శక్తి (_ P) :
# Question: లీగ్ ఆఫ్ నేషన్స్ కౌన్సిల్ నుండి యునైటెడ్ స్టేట్స్ ఎందుకు మినహాయించబడింది?
# Answer: వెర్సైల్లెస్ ఒప్పందాన్ని ఆమోదించడానికి వ్యతిరేకంగా ఓటు వేసింది, తద్వారా లీగ్లో అమెరికన్ భాగస్వామ్యాన్ని నిరోధించింది.
# Start position: 408
# Neighboring characters: 408: వ 409: ె 410: ర 411: ్ 412: స 413: ై 414: ల 415: ్ 416: ల 417: ె 418: స 419: ్
# Context snippet: 20 న వెర్సైల్లెస్ ఒప్పందాన్ని ఆమోదించడానికి వ్యతిరేకంగా ఓటు వేసింది, తద్వారా లీగ్లో అమెరికన్ భాగస్వామ్యాన్ని నిరోధించింది.
# -----------------------------------------------
# -----------------------------------------------
# 407. పక్షి. :
# Question: ఏ రకమైన పక్షులు సాధారణంగా చేపలు పట్టడం, మొక్కలను తినడం లేదా సముద్రపు దొంగతనం ద్వారా తింటాయి?
# Answer: జల పక్షులు
# Start position: 399
# Neighboring characters: 399: జ 400: ల 401:  402: ప 403: క 404: ్ 405: ష 406: ు 407: ల 408: ు 409:  410: స
# Context snippet: ్చు. జల పక్షులు సాధా
# -----------------------------------------------
# -----------------------------------------------
# 408. క్వింగ్ రాజవంశం (_ d) :
# Question: జియాంగ్ సైన్యానికి ఏ పేరు పెట్టారు?
# Answer: ఇది హునాన్ ప్రాంతం పేరు
# Start position: 620
# Neighboring characters: 620: ఇ 621: ద 622: ి 623:  624: హ 625: ు 626: న 627: ా 628: న 629: ్ 630:  631: ప
# Context snippet: ంది, ఇది హునాన్ ప్రాంతం పేరు పెట్
# -----------------------------------------------
# -----------------------------------------------
# 409. అమెరికాలోని స్వదేశీ ప్రజలు :
# Question: ఉత్తర మరియు దక్షిణ అమెరికా ఖండాలలో మానవులు ఎప్పుడు నివసించారు?
# Answer: చివరి
# Start position: 267
# Neighboring characters: 267: చ 268: ి 269: వ 270: ర 271: ి 272:  273: ఖ 274: ం 275: డ 276: ా 277: ల 278: ు
# Context snippet: లోని చివరి ఖండా
# -----------------------------------------------
# -----------------------------------------------
# 410. ఎరుపు. :
# Question: 1869 హైవే చట్టం దేనిని రద్దు చేసింది?
# Plausible Answer: మోటారింగ్ ప్రారంభ రోజుల్లో, మోటారు కార్లు ఎర్ర జెండాతో ఉన్న వ్యక్తిని అనుసరించాల్సి వచ్చింది, అతను గుర్రపు వాహనాలను హెచ్చరిస్తాడు,
# Start position: 247
# Neighboring characters: 247: మ 248: ో 249: ట 250: ా 251: ర 252: ి 253: ం 254: గ 255: ్ 256:  257: ప 258: ్
# Context snippet: ్లో, మోటారింగ్ ప్రారంభ రోజుల్లో, మోటారు కార్లు ఎర్ర జెండాతో ఉన్న వ్యక్తిని అనుసరించాల్సి వచ్చింది, అతను గుర్రపు వాహనాలను హెచ్చరిస్తాడు, లోకో
# -----------------------------------------------
# 411. ఈజిప్ట్ :
# Question: తూర్పున ఈజిప్టుకు సరిహద్దుగా ఏ సముద్రం ఉంది?
# Answer: ఎర్ర సముద్రం,
# Start position: 534
# Neighboring characters: 534: ఎ 535: ర 536: ్ 537: ర 538:  539: స 540: మ 541: ు 542: ద 543: ్ 544: ర 545: ం
# Context snippet: ిణాన ఎర్ర సముద్రం, దక్ష
# -----------------------------------------------
# -----------------------------------------------
# 412. మొజాయిక్ :
# Question: లుక్కాలోని బాసిలికా డి శాన్ ఫ్రెడియానోలో ఏ బొమ్మను వర్ణించే పెద్ద బంగారు మొజాయిక్ ముఖభాగం ఉంది?
# Answer: క్రీస్తు
# Start position: 367
# Neighboring characters: 367: క 368: ్ 369: ర 370: ీ 371: స 372: ్ 373: త 374: ు 375:  376: ఆ 377: ర 378: ో
# Context snippet: ులతో క్రీస్తు ఆరోహ
# -----------------------------------------------
# -----------------------------------------------
# 413. విశ్వవిద్యాలయం :
# Question: ఏ విశ్వవిద్యాలయంలో బోధన మరింత కేంద్రీకృతమై, సాధారణమైనది కాదు?
# Plausible Answer: ఆక్స్ఫర్డ్ విశ్వవిద్యాలయంలోని
# Start position: 390
# Neighboring characters: 390: ఆ 391: క 392: ్ 393: స 394: ్ 395: ఫ 396: ర 397: ్ 398: డ 399: ్ 400:  401: వ
# Context snippet: ంది. ఆక్స్ఫర్డ్ విశ్వవిద్యాలయంలోని వ్యవ
# -----------------------------------------------
# 414. మతం _ పురాతన _ రోమ్లో :
# Question: కాలానుగుణ పండుగలు ఏ సంప్రదాయాలను కలిగి ఉన్నాయి?
# Answer: స్థానిక
# Start position: 277
# Neighboring characters: 277: స 278: ్ 279: థ 280: ా 281: న 282: ి 283: క 284:  285: స 286: ం 287: ప 288: ్
# Context snippet: ివిధ స్థానిక సంప్
# -----------------------------------------------
# -----------------------------------------------
# 415. యూట్యూబ్ :
# Question: ఇట్ గెట్స్ బెటర్ ప్రాజెక్ట్ వీడియోకు ఇంత భారీ స్పందన రావడానికి ఎంత సమయం పట్టింది?
# Answer: రెండు నెలల్లోనే
# Start position: 167
# Neighboring characters: 167: ర 168: ె 169: ం 170: డ 171: ు 172:  173: న 174: ె 175: ల 176: ల 177: ్ 178: ల
# Context snippet: ంది, రెండు నెలల్లోనే అమెర
# -----------------------------------------------
# -----------------------------------------------
# 416. యునైటెడ్ స్టేట్స్ లో చర్చి మరియు రాష్ట్రాలను వేరు చేయడం :
# Question: ఎవరి విభజన భావనలు చాలాకాలంగా వాదించబడుతున్నాయి?
# Answer: జెఫెర్సన్ మరియు జేమ్స్ మాడిసన్
# Start position: 0
# Neighboring characters: 0: జ 1: ె 2: ఫ 3: ె 4: ర 5: ్ 6: స 7: న 8: ్ 9:  10: మ 11: ర
# Context snippet: జెఫెర్సన్ మరియు జేమ్స్ మాడిసన్ యొక్
# -----------------------------------------------
# -----------------------------------------------
# 417. ప్రొటెస్టెంటిజం :
# Question: మూడవ గొప్ప మేల్కొలుపుతో ఏ ఉద్యమం అనుబంధించబడింది?
# Answer: సామాజిక సువార్త ఉద్యమంతో
# Start position: 430
# Neighboring characters: 430: స 431: ా 432: మ 433: ా 434: జ 435: ి 436: క 437:  438: స 439: ు 440: వ 441: ా
# Context snippet:  ఇది సామాజిక సువార్త ఉద్యమంతో అనుబ
# -----------------------------------------------
# -----------------------------------------------
# 418. బ్రాస్% C3% ADlia :
# Question: బ్రెసిలియా జిడిపి ఎంత?
# Answer: లో 99.5 కోట్ల రియాస్ల
# Start position: 121
# Neighboring characters: 121: ల 122: ో 123:  124: 9 125: 9 126: . 127: 5 128:  129: క 130: ో 131: ట 132: ్
# Context snippet:  పి. లో 99.5 కోట్ల రియాస్ల అత్య
# -----------------------------------------------
# -----------------------------------------------
# 419. గ్రీస్ యొక్క ఆర్థిక వ్యవస్థ :
# Question: యూరోను గ్రీస్ తన కరెన్సీగా ఎప్పుడు స్వీకరించింది?
# Answer: 2001లో
# Start position: 272
# Neighboring characters: 272: 2 273: 0 274: 0 275: 1 276: ల 277: ో 278:  279: గ 280: ్ 281: ర 282: ీ 283: స
# Context snippet: ంది. 2001లో గ్రీ
# -----------------------------------------------
# -----------------------------------------------
# 420. పార్టీ _ లీడర్ _ ఆఫ్ _ ది _ యునైటెడ్ _ స్టేట్స్ _ హౌస్ _ ఆఫ్ _ రిప్రజెంటేటివ్స్ :
# Question: DCCC నాయకత్వ PAC లను ఎందుకు ఏర్పాటు చేస్తుంది?
# Plausible Answer: వారు తమ పార్టీ హౌస్ అభ్యర్థులకు నిధులను సేకరించి పంపిణీ
# Start position: 274
# Neighboring characters: 274: వ 275: ా 276: ర 277: ు 278:  279: త 280: మ 281:  282: ప 283: ా 284: ర 285: ్
# Context snippet: ారు; వారు తమ పార్టీ హౌస్ అభ్యర్థులకు నిధులను సేకరించి పంపిణీ చేయడ
# -----------------------------------------------
# 421. అర్మేనియన్లు :
# Question: అర్మేనియా ఒలింపిక్ పతకాలు గెలవడం ఎప్పుడు ప్రారంభించింది?
# Answer: 1952 వేసవి
# Start position: 199
# Neighboring characters: 199: 1 200: 9 201: 5 202: 2 203:  204: వ 205: ే 206: స 207: వ 208: ి 209:  210: ఒ
# Context snippet: పతకం 1952 వేసవి ఒలిం
# -----------------------------------------------
# -----------------------------------------------
# 422. యెహోవా% 27s _ సాక్షులు :
# Question: సాంప్రదాయ సెలవులన్నీ దేనిని ప్రతిబింబిస్తాయని యెహోవాసాక్షులు భావిస్తారు?
# Answer: ప్రపంచంపై సాతాను నియంత్రణను
# Start position: 727
# Neighboring characters: 727: ప 728: ్ 729: ర 730: ప 731: ం 732: చ 733: ం 734: ప 735: ై 736:  737: స 738: ా
# Context snippet: వులు ప్రపంచంపై సాతాను నియంత్రణను ప్రత
# -----------------------------------------------
# -----------------------------------------------
# 423. Dwight_D._Eisenhower :
# Question: డార్లాన్ ఏ రోజున మరణించాడు?
# Answer: డిసెంబర్ 24న
# Start position: 678
# Neighboring characters: 678: డ 679: ి 680: స 681: ె 682: ం 683: బ 684: ర 685: ్ 686:  687: 2 688: 4 689: న
# Context snippet: ాడు. డిసెంబర్ 24న డార్
# -----------------------------------------------
# -----------------------------------------------
# 424. ది _ బ్రోంక్స్ :
# Question: 2009 నాటికి బ్రోంక్స్లో ఎంత భాగం హిస్పానిక్ కాని తెల్లగా ఉంది?
# Answer: 34.4%
# Start position: 281
# Neighboring characters: 281: 3 282: 4 283: . 284: 4 285: % 286:  287: న 288: ు 289: ం 290: డ 291: ి 292:
# Context snippet: 0 లో 34.4% నుండ
# -----------------------------------------------
# -----------------------------------------------
# 425. ఫైనాన్షియల్ _ క్రైసిస్ _ ఆఫ్ _ 2007% E 2%80% 9308 :
# Question: అనేక మంది పండితుల అభిప్రాయం ప్రకారం ప్రమాద స్థాయిలను ఎలా బహిర్గతం చేయాలి?
# Answer: సూటిగా, సులభంగా అర్థం చేసుకోగలిగే ఆకృతిలో
# Start position: 397
# Neighboring characters: 397: స 398: ూ 399: ట 400: ి 401: గ 402: ా 403: , 404:  405: స 406: ు 407: ల 408: భ
# Context snippet: ిలను సూటిగా, సులభంగా అర్థం చేసుకోగలిగే ఆకృతిలో వెల్
# -----------------------------------------------
# -----------------------------------------------
# 426. పోర్చుగల్ :
# Question: ప్రధాన మంత్రి జోస్ సోక్రటీస్ ఏప్రిల్ 6,2011న ఏమి ప్రకటించారు?
# Answer: దేశం IMF మరియు యూరోపియన్ ఫైనాన్షియల్ స్టెబిలిటీ ఫెసిలిటీ నుండి ఆర్థిక సహాయాన్ని అభ్యర్థిస్తుందని
# Start position: 216
# Neighboring characters: 216: ద 217: ే 218: శ 219: ం 220:  221: I 222: M 223: F 224:  225: మ 226: ర 227: ి
# Context snippet: ుగా, దేశం IMF మరియు యూరోపియన్ ఫైనాన్షియల్ స్టెబిలిటీ ఫెసిలిటీ నుండి ఆర్థిక సహాయాన్ని అభ్యర్థిస్తుందని ప్రక
# -----------------------------------------------
# -----------------------------------------------
# 427. మానవతావాదం :
# Question: ఈ గ్రంథాలు మొదట పెద్ద సంఖ్యలో ప్రజలను ఎప్పుడు చేరుకోగలవు?
# Answer: ఎరాస్మస్,
# Start position: 181
# Neighboring characters: 181: ఎ 182: ర 183: ా 184: స 185: ్ 186: మ 187: స 188: ్ 189: , 190:  191: వ 192: ల
# Context snippet: వాది ఎరాస్మస్, వల్ల
# -----------------------------------------------
# -----------------------------------------------
# 428. జియోలాజికల్ _ హిస్టరీ _ ఆఫ్ _ ఎర్త్ :
# Question: కాంబ్రియన్ యుగంలో ఏ ఖండం భూమి యొక్క దక్షిణ భాగానికి మారింది?
# Answer: గోండ్వానా
# Start position: 472
# Neighboring characters: 472: గ 473: ో 474: ం 475: డ 476: ్ 477: వ 478: ా 479: న 480: ా 481:  482: ద 483: క
# Context snippet: ాయి. గోండ్వానా దక్ష
# -----------------------------------------------
# -----------------------------------------------
# 429. పోలీసులు :
# Question: రియో తన మొదటి పోలీసు ఇన్స్పెక్టర్ను ఎప్పుడు పొందింది?
# Plausible Answer: 1566లో,
# Start position: 0
# Neighboring characters: 0: 1 1: 5 2: 6 3: 6 4: ల 5: ో 6: , 7:  8: ర 9: ి 10: య 11: ో
# Context snippet: 1566లో, రియో
# -----------------------------------------------
# 430. జాత్యహంకారం :
# Question: "పాక్షికంగా" సమస్యను పరిష్కరించడంలో, అప్పీల్స్ ఛాంబర్ ఈ భాగం దేనిలో గణనీయమైన భాగంగా ఉండాలని కనుగొంది?
# Answer: ఆ సమూహంలో
# Start position: 481
# Neighboring characters: 481: ఆ 482:  483: స 484: మ 485: ూ 486: హ 487: ం 488: ల 489: ో 490:  491: గ 492: ణ
# Context snippet: భాగం ఆ సమూహంలో గణనీ
# -----------------------------------------------
# -----------------------------------------------
# 431. సెయింట్ _ బార్త్% C3% A9లేమీ :
# Question: గాలికి పక్కగా ఎన్ని బీచ్లు ఉన్నాయి?
# Plausible Answer: 15
# Start position: 109
# Neighboring characters: 109: 1 110: 5 111:  112: ఈ 113: త 114: క 115: ు 116:  117: అ 118: న 119: ు 120: వ
# Context snippet: టిలో 15 ఈతకు
# -----------------------------------------------
# 432. తజికిస్తాన్ :
# Question: ఖుజాంద్ లో చైనా సైనికులపై నిరసనకారులు దేని కోసం దాడి చేశారు?
# Plausible Answer: మొదటి ప్రపంచ యుద్ధంలో బలవంతంగా సైనికులను చేర్చుకునే బెదిరింపుపై
# Start position: 365
# Neighboring characters: 365: మ 366: ొ 367: ద 368: ట 369: ి 370:  371: ప 372: ్ 373: ర 374: ప 375: ం 376: చ
# Context snippet: ంది. మొదటి ప్రపంచ యుద్ధంలో బలవంతంగా సైనికులను చేర్చుకునే బెదిరింపుపై 1916
# -----------------------------------------------
# 433. యూనివర్శిటీ _ ఆఫ్ _ నోట్రే _ డేమ్ :
# Question: జాన్ అగస్టీన్ జహమ్ యొక్క జీవితకాలం ఏమిటి?
# Answer: (1851-1921),
# Start position: 336
# Neighboring characters: 336: ( 337: 1 338: 8 339: 5 340: 1 341: - 342: 1 343: 9 344: 2 345: 1 346: ) 347: ,
# Context snippet: జహమ్ (1851-1921), 23 స
# -----------------------------------------------
# -----------------------------------------------
# 434. మానవ శాస్త్రం :
# Question: అభిజ్ఞా శాస్త్రాలను వివరించడానికి అభిజ్ఞా మానవ శాస్త్రవేత్తలు ఏమి ఉపయోగిస్తారు?
# Plausible Answer: సాంస్కృతిక ఆవిష్కరణ
# Start position: 384
# Neighboring characters: 384: స 385: ా 386: ం 387: స 388: ్ 389: క 390: ృ 391: త 392: ి 393: క 394:  395: ఆ
# Context snippet: ానం, సాంస్కృతిక ఆవిష్కరణ మరియ
# -----------------------------------------------
# 435. మోంటానా :
# Question: ఫోర్ట్ పెక్ రిజర్వాయర్ను ఏ సంవత్సరంలో జాతీయ సుందరమైన నదిగా నియమించారు?
# Answer: 1976లో
# Start position: 448
# Neighboring characters: 448: 1 449: 9 450: 7 451: 6 452: ల 453: ో 454:  455: న 456: ే 457: ష 458: న 459: ల
# Context snippet: రణను 1976లో నేషన
# -----------------------------------------------
# -----------------------------------------------
# 436. పంజాబ్, _ పాకిస్తాన్ :
# Question: పాకిస్తాన్ చక్కెరలో పంజాబ్ ఎంత ఉత్పత్తి చేస్తుంది?
# Answer: 69 శాతం
# Start position: 456
# Neighboring characters: 456: 6 457: 9 458:  459: శ 460: ా 461: త 462: ం 463:  464: చ 465: క 466: ్ 467: క
# Context snippet: ులు, 69 శాతం చక్క
# -----------------------------------------------
# -----------------------------------------------
# 437. రిచ్మండ్, _ వర్జీనియా :
# Question: 2000లో, రిచ్మండ్ నివాసితులలో ఎంత శాతం మంది బహుళ జాతి ప్రజలు ఉన్నారు?
# Answer: 1.5%
# Start position: 397
# Neighboring characters: 397: 1 398: . 399: 5 400: % 401:  402: ర 403: ె 404: ం 405: డ 406: ు 407:  408: ల
# Context snippet: రియు 1.5% రెండ
# -----------------------------------------------
# -----------------------------------------------
# 438. ఇన్ఫెక్షన్. :
# Question: విరేచనాల మరణాలలో ఎక్కువ శాతం ఎవరు ఉన్నారు?
# Answer: పిల్లలు
# Start position: 315
# Neighboring characters: 315: ప 316: ి 317: ల 318: ్ 319: ల 320: ల 321: ు 322:  323: క 324: ూ 325: డ 326: ా
# Context snippet: ాలలో పిల్లలు కూడా
# -----------------------------------------------
# -----------------------------------------------
# 439. వేట :
# Question: మెసొపొటేమియాలో పూజించబడే ప్రధాన దేవుడు ఎవరు?
# Plausible Answer: కొమ్ముల దేవుడు సెర్నన్నోస్
# Start position: 233
# Neighboring characters: 233: క 234: ొ 235: మ 236: ్ 237: మ 238: ు 239: ల 240:  241: ద 242: ే 243: వ 244: ు
# Context snippet: యతను కొమ్ముల దేవుడు సెర్నన్నోస్ మరియ
# -----------------------------------------------
# 440. ఖాట్మండు :
# Question: ఖాట్మండు నివాసితులు సాధారణంగా అల్పాహారం కోసం ఏమి తింటారు?
# Answer: మోమో లేదా మోమో.
# Start position: 816
# Neighboring characters: 816: మ 817: ో 818: మ 819: ో 820:  821: ల 822: ే 823: ద 824: ా 825:  826: మ 827: ో
# Context snippet: హారం మోమో లేదా మోమో.
# -----------------------------------------------
# -----------------------------------------------
# 441. మయోకార్డియల్ ఇన్ఫార్క్షన్ (_ I) :
# Question: అభివృద్ధి చెందుతున్న పదంలో ఐహెచ్డి ఎప్పుడు పెద్ద సమస్యగా మారింది?
# Plausible Answer: 2004
# Start position: 119
# Neighboring characters: 119: 2 120: 0 121: 0 122: 4 123:  124: న 125: ా 126: ట 127: ి 128: క 129: ి 130:
# Context snippet: ంలో, 2004 నాటి
# -----------------------------------------------
# 442. విషయం. :
# Question: ఫెర్మియన్లకు వసతి కల్పించడానికి ఏది కుంచించుకుపోతుంది?
# Plausible Answer: (ఫెర్మి శక్తి అని పిలుస్తారు) మరియు వాయువు యొక్క పీడనం
# Start position: 422
# Neighboring characters: 422: ( 423: ఫ 424: ె 425: ర 426: ్ 427: మ 428: ి 429:  430: శ 431: క 432: ్ 433: త
# Context snippet: క్తి (ఫెర్మి శక్తి అని పిలుస్తారు) మరియు వాయువు యొక్క పీడనం చాలా
# -----------------------------------------------

# %%
    
# Example usage
if __name__ == "__main__":
    # Replace with your dataset path
    #dataset_path = "../alpha 2.0/valid_og_nums.json"
    dataset_path = "/Users/santhoshrishimarkonda/Downloads/SQUAD TEL DATA/squad2.0_telugu_val.json"
    process_squad_dataset(dataset_path)
# Out:
# 1. బియాన్స్ :
# Question: శ్రీమతి కార్టర్ షో లిమిటెడ్ ఎడిషన్ ఏ సంవత్సరంలో విడుదలైంది?
# Answer: 2013లో,
# Start position: 592
# Neighboring characters: 592: 2 593: 0 594: 1 595: 3 596: ల 597: ో 598: , 599:  600: హ 601: ీ 602: ట 603: ్
# Context snippet: ంది. 2013లో, హీట్
# -----------------------------------------------
# -----------------------------------------------
# 2. ఫ్రెడెరిక్ _ చోపిన్ :
# Question: చోపిన్ తన సంగీతాన్ని ప్రపంచానికి తీసుకెళ్లడం ప్రారంభించినప్పుడు, అతనితో ఆస్ట్రియాకు వెళ్ళిన వ్యక్తి చివరి పేరు ఏమిటి?
# Answer: వోయ్సెచోవ్స్కీ
# Start position: 255
# Neighboring characters: 255: వ 256: ో 257: య 258: ్ 259: స 260: ె 261: చ 262: ో 263: వ 264: ్ 265: స 266: ్
# Context snippet: డు". వోయ్సెచోవ్స్కీతో, అ
# -----------------------------------------------
# -----------------------------------------------
# 3. మింగ్ రాజవంశం సమయంలో చైనా-టిబెటన్ సంబంధాలు :
# Question: టిబెట్పై మింగ్ రాజసభకు పూర్తి సార్వభౌమాధికారం ఉందని ఎవరు విశ్వసించారు?
# Answer: వాంగ్ మరియు నైమా
# Start position: 90
# Neighboring characters: 90: వ 91: ా 92: ం 93: గ 94: ్ 95:  96: మ 97: ర 98: ి 99: య 100: ు 101:
# Context snippet: ారని వాంగ్ మరియు నైమా వాది
# -----------------------------------------------
# -----------------------------------------------
# 4. ఐప్యాడ్ :
# Question: ఆపిల్ తన మొత్తం కేటలాగ్ డిఆర్ఎమ్ రహితంగా ఉంటుందని ఏ సమయానికి అంచనా వేసింది?
# Answer: ఆపిల్ 2009
# Start position: 827
# Neighboring characters: 827: ఆ 828: ప 829: ి 830: ల 831: ్ 832:  833: 2 834: 0 835: 0 836: 9 837:  838: జ
# Context snippet: ంది, ఆపిల్ 2009 జనవర
# -----------------------------------------------
# -----------------------------------------------
# 5. ది _ లెజెండ్ _ ఆఫ్ _ జేల్డాః _ ట్విలైట్ _ ప్రిన్సెస్ :
# Question: లింక్కు సహాయపడే మర్మమైన జీవి పేరు ఏమిటి?
# Answer: మిడ్నా
# Start position: 222
# Neighboring characters: 222: మ 223: ి 224: డ 225: ్ 226: న 227: ా 228:  229: అ 230: న 231: ే 232:  233: మ
# Context snippet: రియు మిడ్నా అనే
# -----------------------------------------------
# -----------------------------------------------
# 6. స్పెక్టర్ (2015-చిత్రం) :
# Question: యుఎస్ మరియు కెనడాలో ప్రివ్యూ ప్రదర్శనలు ఎంత డబ్బు సంపాదించాయి?
# Answer: $5.25 మిలియన్లు
# Start position: 260
# Neighboring characters: 260: $ 261: 5 262: . 263: 2 264: 5 265:  266: మ 267: ి 268: ల 269: ి 270: య 271: న
# Context snippet: ుండి $5.25 మిలియన్లు మరియ
# -----------------------------------------------
# -----------------------------------------------
# 7. 2008 సిచువాన్ భూకంపం :
# Question: చీలిక ఎంతకాలం కొనసాగింది?
# Answer: 120 సెకన్లకు
# Start position: 348
# Neighboring characters: 348: 1 349: 2 350: 0 351:  352: స 353: ె 354: క 355: న 356: ్ 357: ల 358: క 359: ు
# Context snippet: ీలిక 120 సెకన్లకు దగ్గ
# -----------------------------------------------
# -----------------------------------------------
# 8. న్యూయార్క్ _ సిటీ :
# Question: మాన్హాటన్ నివాసితులలో ఎంత శాతం మంది ఆటోమొబైల్ కలిగి ఉన్నారు?
# Answer: 22 శాతం
# Start position: 464
# Neighboring characters: 464: 2 465: 2 466:  467: శ 468: ా 469: త 470: ం 471:  472: మ 473: ం 474: ద 475: ి
# Context snippet: ేవలం 22 శాతం మంది
# -----------------------------------------------
# -----------------------------------------------
# 9. ఒక మోకింగ్బర్డ్ను చంపడానికి (_ K) :
# Question: ది అమెరికన్ లైబ్రరీ అసోసియేషన్ ప్రకారం, 2000 నుండి 2009 వరకు అత్యంత తరచుగా సవాలు చేయబడిన పుస్తకాలలో ఈ పుస్తకానికి ఏ ర్యాంక్ ఉంది?
# Answer: 21
# Start position: 406
# Neighboring characters: 406: 2 407: 1 408:  409: వ 410:  411: స 412: ్ 413: థ 414: ా 415: న 416: ం 417: ల
# Context snippet: ాలలో 21 వ స్
# -----------------------------------------------
# -----------------------------------------------
# 10. సౌరశక్తి (_ E) :
# Question: 2015లో సౌరశక్తి ద్వారా భూగోళాన్ని చుట్టుముట్టిన విమానం పేరు ఏమిటి?
# Answer: సోలార్ రైజర్
# Start position: 94
# Neighboring characters: 94: స 95: ో 96: ల 97: ా 98: ర 99: ్ 100:  101: ర 102: ై 103: జ 104: ర 105: ్
# Context snippet: 29న, సోలార్ రైజర్ సౌరశ
# -----------------------------------------------
# -----------------------------------------------
# 11. కాన్యే _ వెస్ట్ :
# Question: కాన్యే వెస్ట్ తన పాస్టెల్ దుస్తుల లైన్ను ఎప్పుడు ప్రకటించాడు?
# Answer: సెప్టెంబరు 2005లో,
# Start position: 0
# Neighboring characters: 0: స 1: ె 2: ప 3: ్ 4: ట 5: ె 6: ం 7: బ 8: ర 9: ు 10:  11: 2
# Context snippet: సెప్టెంబరు 2005లో, వెస్
# -----------------------------------------------
# -----------------------------------------------
# 12. బౌద్ధమతం :
# Question: నిర్వాణ మరియు ఏ పదం ఒకే అర్ధాన్ని కలిగి ఉన్నాయి?
# Answer: బోధి
# Start position: 0
# Neighboring characters: 0: బ 1: ో 2: ధ 3: ి 4:  5: మ 6: ర 7: ి 8: య 9: ు 10:  11: న
# Context snippet: బోధి మరియ
# -----------------------------------------------
# -----------------------------------------------
# 13. అమెరికన్ ఐడల్ (_ I) :
# Question: ఏ సంవత్సరంలో అమెరికన్ ఐడల్ తన పదకొండవ సీజన్ను మొదటిసారి ప్రసారం చేసింది?
# Answer: 18,2012న
# Start position: 15
# Neighboring characters: 15: 1 16: 8 17: , 18: 2 19: 0 20: 1 21: 2 22: న 23:  24: ప 25: ్ 26: ర
# Context snippet: నవరి 18,2012న ప్రద
# -----------------------------------------------
# -----------------------------------------------
# 14. కుక్క. :
# Question: ప్రజల నివాసాలను శుభ్రంగా ఉంచడానికి కుక్కలు ఏమి శుభ్రం చేశాయి?
# Answer: ఆహార స్క్రాప్లను
# Start position: 103
# Neighboring characters: 103: ఆ 104: హ 105: ా 106: ర 107:  108: స 109: ్ 110: క 111: ్ 112: ర 113: ా 114: ప
# Context snippet: ్కలు ఆహార స్క్రాప్లను శుభ్
# -----------------------------------------------
# -----------------------------------------------
# 15. 2008 _ సమ్మర్ _ ఒలింపిక్స్ _ టార్చ్ _ రిలే :
# Question: దీపం యొక్క షెడ్యూల్ బేరర్ ఎవరు బహిష్కరించారు?
# Answer: తల్లి రాజావోంగ్సే నరిస్సార చక్రవర్తిని
# Start position: 800
# Neighboring characters: 800: త 801: ల 802: ్ 803: ల 804: ి 805:  806: ర 807: ా 808: జ 809: ా 810: వ 811: ో
# Context snippet: మోసే తల్లి రాజావోంగ్సే నరిస్సార చక్రవర్తిని బహిష
# -----------------------------------------------
# -----------------------------------------------
# 16. జీనోమ్ :
# Question: వీసెన్బాచ్ మరియు అతని సహచరులు ఎక్కడ పనిచేశారు?
# Answer: జెనోస్కోప్లో
# Start position: 330
# Neighboring characters: 330: జ 331: ె 332: న 333: ో 334: స 335: ్ 336: క 337: ో 338: ప 339: ్ 340: ల 341: ో
# Context snippet: లోని జెనోస్కోప్లో జీన్
# -----------------------------------------------
# -----------------------------------------------
# 17. సమగ్ర పాఠశాల (_ S) :
# Question: మార్గరెట్ థాచర్ విద్యాశాఖ కార్యదర్శిగా ఉన్నప్పుడు ఏ పార్టీ అధికారంలో ఉండేది?
# Answer: కన్జర్వేటివ్
# Start position: 29
# Neighboring characters: 29: క 30: న 31: ్ 32: జ 33: ర 34: ్ 35: వ 36: ే 37: ట 38: ి 39: వ 40: ్
# Context snippet: ొత్త కన్జర్వేటివ్ ప్రభ
# -----------------------------------------------
# -----------------------------------------------
# 18. రిపబ్లిక్ _ ఆఫ్ _ ది _ కాంగో :
# Question: సూర్యుడు ఉదయించినప్పుడు కాంగోలో సగటు ఉష్ణోగ్రత ఎంత?
# Answer: °సి (75 °ఎఫ్)
# Start position: 103
# Neighboring characters: 103: ° 104: స 105: ి 106:  107: ( 108: 7 109: 5 110:  111: ° 112: ఎ 113: ఫ 114: ్
# Context snippet: న 24 °సి (75 °ఎఫ్) మరియ
# -----------------------------------------------
# -----------------------------------------------
# 19. ప్రధాన మంత్రి (_ m) :
# Question: రాణి అన్నే ఏకకాలంలో ఉపయోగించిన ఇద్దరు మంత్రులు ఎవరు?
# Answer: హార్లే మరియు సెయింట్ జాన్
# Start position: 375
# Neighboring characters: 375: హ 376: ా 377: ర 378: ్ 379: ల 380: ే 381:  382: మ 383: ర 384: ి 385: య 386: ు
# Context snippet: రులు హార్లే మరియు సెయింట్ జాన్ అధిక
# -----------------------------------------------
# -----------------------------------------------
# 20. ఇన్స్టిట్యూట్ _ ఆఫ్ _ టెక్నాలజీ :
# Question: ఇండోనేషియాలో ఎన్ని ప్రభుత్వ యాజమాన్యంలోని ప్రభుత్వ సాంకేతిక సంస్థలు ఉన్నాయి?
# Answer: నాలుగు
# Start position: 45
# Neighboring characters: 45: న 46: ా 47: ల 48: ు 49: గ 50: ు 51:  52: ప 53: ్ 54: ర 55: భ 56: ు
# Context snippet: ందిన నాలుగు ప్రభ
# -----------------------------------------------
# -----------------------------------------------
# 21. వెబ్యాక్ యంత్రం (_ M) :
# Question: robots.txt అడ్డంకిని నిలిపివేయడానికి కాలిఫోర్నియాను ఎందుకు అనుమతించారు?
# Plausible Answer: వారు కోరిన ఆర్కైవ్ చేసిన పేజీలను తిరిగి పొందడానికి చోర్డియంట్ను అనుమతించడానికి
# Start position: 128
# Neighboring characters: 128: వ 129: ా 130: ర 131: ు 132:  133: క 134: ో 135: ర 136: ి 137: న 138:  139: ఆ
# Context snippet: రియు వారు కోరిన ఆర్కైవ్ చేసిన పేజీలను తిరిగి పొందడానికి చోర్డియంట్ను అనుమతించడానికి robo
# -----------------------------------------------
# 22. డచ్ రిపబ్లిక్ (_ R) :
# Question: యునైటెడ్ ప్రావిన్సులకు కేటాయించిన సరిహద్దు భూభాగాలను దేని పేరుతో పిలిచేవారు?
# Answer: సమాఖ్య పాలనలో ఉన్న జనరల్ ల్యాండ్స్ (జనరలిటైట్స్ల్యాండెన్).
# Start position: 102
# Neighboring characters: 102: స 103: మ 104: ా 105: ఖ 106: ్ 107: య 108:  109: ప 110: ా 111: ల 112: న 113: ల
# Context snippet:  అవి సమాఖ్య పాలనలో ఉన్న జనరల్ ల్యాండ్స్ (జనరలిటైట్స్ల్యాండెన్). అవి
# -----------------------------------------------
# -----------------------------------------------
# 23. సింబయోసిస్ :
# Question: అమెన్సాలిస్టిక్ సంబంధంలో ఐబెక్స్ ఏ జీవులతో ఉంటుంది?
# Answer: వీవిల్స్
# Start position: 434
# Neighboring characters: 434: వ 435: ీ 436: వ 437: ి 438: ల 439: ్ 440: స 441: ్ 442:  443: మ 444: ధ 445: ్
# Context snippet: ందిన వీవిల్స్ మధ్య
# -----------------------------------------------
# -----------------------------------------------
# 24. కెనడియన్ _ సాయుధ _ దళాలు :
# Question: సాయుధ దళాలలో సుమారు ఎంత మంది సభ్యులు ఉన్నారు?
# Answer: దళాల 115,349
# Start position: 6
# Neighboring characters: 6: ద 7: ళ 8: ా 9: ల 10:  11: 1 12: 1 13: 5 14: , 15: 3 16: 4 17: 9
# Context snippet: ాయుధ దళాల 115,349 మంది
# -----------------------------------------------
# -----------------------------------------------
# 25. కార్డినల్ _ (కాథలిక్కులు) :
# Question: ఏ విధులు నిర్వర్తించడానికి సన్యాసినులకు అనుమతి ఉంది?
# Plausible Answer: మాస్ జరుపుకోవడానికి మరియు ఒప్పుకోలు వినడానికి మరియు చర్చి సిబ్బందితో సమన్వయంతో వారి నామమాత్ర చర్చిలకు సందర్శనలు మరియు తీర్థయాత్రలకు నాయకత్వం వహించడానికి
# Start position: 330
# Neighboring characters: 330: మ 331: ా 332: స 333: ్ 334:  335: జ 336: ర 337: ు 338: ప 339: ు 340: క 341: ో
# Context snippet: వారు మాస్ జరుపుకోవడానికి మరియు ఒప్పుకోలు వినడానికి మరియు చర్చి సిబ్బందితో సమన్వయంతో వారి నామమాత్ర చర్చిలకు సందర్శనలు మరియు తీర్థయాత్రలకు నాయకత్వం వహించడానికి అనుమ
# -----------------------------------------------
# 26. ఇరానియన్ భాషలు (_ L) :
# Question: పాశ్చాత్య భాషలు ఉపయోగించే వర్ణమాల ఎక్కడ నుండి వచ్చింది?
# Plausible Answer: అరామిక్
# Start position: 436
# Neighboring characters: 436: అ 437: ర 438: ా 439: మ 440: ి 441: క 442: ్ 443: - 444: ఉ 445: త 446: ్ 447: ప
# Context snippet: ివిధ అరామిక్-ఉత్ప
# -----------------------------------------------
# 27. లైటింగ్ :
# Question: భవనాల చుట్టూ పదునైన నీడ ఏర్పడటానికి కారణం ఏమిటి?
# Answer: మెరుపు
# Start position: 511
# Neighboring characters: 511: మ 512: ె 513: ర 514: ు 515: ప 516: ు 517:  518: చ 519: ా 520: ల 521: ా 522:
# Context snippet: ణకు, మెరుపు చాలా
# -----------------------------------------------
# -----------------------------------------------
# 28. యునైటెడ్ స్టేట్స్ రాజ్యాంగం కింద అధికారాల విభజన :
# Question: ఆండ్రూ జాన్సన్ యొక్క వీటోల్లో ఎన్నింటిని కాంగ్రెస్ తిరస్కరించింది
# Answer: పదిహేను
# Start position: 365
# Neighboring characters: 365: ప 366: ద 367: ి 368: హ 369: ే 370: న 371: ు 372:  373: క 374: ా 375: ం 376: గ
# Context snippet: ల్లో పదిహేను కాంగ
# -----------------------------------------------
# -----------------------------------------------
# 29. ఆర్కిటెక్చర్ :
# Question: సాధారణ సలహాలు కాకుండా గ్రంథాలలో ఏమి ఉన్నాయి?
# Answer: నిర్దిష్ట అధికారిక సూచనలు
# Start position: 87
# Neighboring characters: 87: న 88: ి 89: ర 90: ్ 91: ద 92: ి 93: ష 94: ్ 95: ట 96:  97: అ 98: ధ
# Context snippet: రియు నిర్దిష్ట అధికారిక సూచనలు లేదా
# -----------------------------------------------
# -----------------------------------------------
# 30. మానవ అభివృద్ధి సూచిక (_ D) :
# Question: హెచ్ఐహెచ్డిఐ ప్రత్యేకంగా దేనిని పరిగణనలోకి తీసుకుంటుంది?
# Plausible Answer: "అసమానతను
# Start position: 61
# Neighboring characters: 61: " 62: అ 63: స 64: మ 65: ా 66: న 67: త 68: న 69: ు 70:  71: ప 72: ర
# Context snippet: నేది "అసమానతను పరిగ
# -----------------------------------------------
# 31. దక్షిణ _ ఐరోపా :
# Question: క్రూసేడర్లు కాన్స్టాంటినోపుల్పై ఎప్పుడు దాడి చేశారు?
# Answer: 1204లో
# Start position: 302
# Neighboring characters: 302: 1 303: 2 304: 0 305: 4 306: ల 307: ో 308:  309: క 310: ా 311: న 312: ్ 313: స
# Context snippet: ారు. 1204లో కాన్
# -----------------------------------------------
# -----------------------------------------------
# 32. బిబిసి _ టెలివిజన్ :
# Question: బిబిసి టూలో ఏ రకమైన కార్యక్రమాలు చూపబడలేదు?
# Answer: సోప్ ఒపెరా లేదా ప్రామాణిక వార్తా కార్యక్రమాలు
# Start position: 368
# Neighboring characters: 368: స 369: ో 370: ప 371: ్ 372:  373: ఒ 374: ప 375: ె 376: ర 377: ా 378:  379: ల
# Context snippet: టూలో సోప్ ఒపెరా లేదా ప్రామాణిక వార్తా కార్యక్రమాలు లేవు
# -----------------------------------------------
# -----------------------------------------------
# 33. ఆర్నాల్డ్ _ స్క్వార్జెనెగర్ :
# Question: 2013లో, స్క్వార్జెనెగర్ అధ్యక్ష ఎన్నికల ప్రచారాన్ని పరిశీలిస్తున్నారని ఏ వార్తాపత్రిక పేర్కొంది?
# Answer: న్యూయార్క్ పోస్ట్
# Start position: 17
# Neighboring characters: 17: న 18: ్ 19: య 20: ూ 21: య 22: ా 23: ర 24: ్ 25: క 26: ్ 27:  28: ప
# Context snippet: 3లో, న్యూయార్క్ పోస్ట్ నివే
# -----------------------------------------------
# -----------------------------------------------
# 34. ప్లైమౌత్ :
# Question: డ్రేక్స్ లీట్ ఎప్పుడు ప్రారంభమైంది?
# Answer: 24 ఏప్రిల్ 1591న
# Start position: 380
# Neighboring characters: 380: 2 381: 4 382:  383: ఏ 384: ప 385: ్ 386: ర 387: ి 388: ల 389: ్ 390:  391: 1
# Context snippet: నికి 24 ఏప్రిల్ 1591న ప్రా
# -----------------------------------------------
# -----------------------------------------------
# 35. సాహసం. :
# Question: మతవిశ్వాశాలను చట్టబద్ధంగా ఎదుర్కోవడానికి వీలు కల్పించే శాసనానికి ముందు చర్చిలో ఏమి లోపించింది?
# Answer: రాష్ట్ర-ప్రాయోజిత మద్దతు లేదు.
# Start position: 311
# Neighboring characters: 311: ర 312: ా 313: ష 314: ్ 315: ట 316: ్ 317: ర 318: - 319: ప 320: ్ 321: ర 322: ా
# Context snippet: నికి రాష్ట్ర-ప్రాయోజిత మద్దతు లేదు. ఈ శా
# -----------------------------------------------
# -----------------------------------------------
# 36. వార్సా ఒప్పందం (_ P) :
# Question: ఏ సంవత్సరంలో స్లొవేకియా నాటోలో చేరింది?
# Answer: 2004లో
# Start position: 145
# Neighboring characters: 145: 2 146: 0 147: 0 148: 4 149: ల 150: ో 151:  152: చ 153: ే 154: ర 155: ా 156: య
# Context snippet: ర్చి 2004లో చేరా
# -----------------------------------------------
# -----------------------------------------------
# 37. భౌతికవాదం :
# Question: మనస్తత్వశాస్త్రం మరియు భూగర్భ శాస్త్రం ఏ స్థాయి భౌతిక శాస్త్రాన్ని ఉపయోగిస్తాయి?
# Plausible Answer: ప్రాథమిక
# Start position: 670
# Neighboring characters: 670: ప 671: ్ 672: ర 673: ా 674: థ 675: మ 676: ి 677: క 678:  679: భ 680: ౌ 681: త
# Context snippet: రణలు ప్రాథమిక భౌతి
# -----------------------------------------------
# 38. క్రైస్తవుడు :
# Question: సాలిబి అనేది సాలిబ్ అనే పదం నుండి వచ్చింది, దీని అర్థం ఏమిటి?
# Answer: "క్రాస్")
# Start position: 96
# Neighboring characters: 96: " 97: క 98: ్ 99: ర 100: ా 101: స 102: ్ 103: " 104: ) 105:  106: న 107: ు
# Context snippet: لిబ్ "క్రాస్") నుండ
# -----------------------------------------------
# -----------------------------------------------
# 39. సోనీ _ మ్యూజిక్ _ ఎంటర్టైన్మెంట్ :
# Question: సోనీకి ఏ వెబ్సైట్పై ఫిర్యాదులు ఉన్నాయి?
# Answer: Wikipedia.org
# Start position: 98
# Neighboring characters: 98: W 99: i 100: k 101: i 102: p 103: e 104: d 105: i 106: a 107: . 108: o 109: r
# Context snippet: నికి Wikipedia.org గురి
# -----------------------------------------------
# -----------------------------------------------
# 40. ఓక్లహోమా _ సిటీ :
# Question: అత్యంత రద్దీగా ఉండే విమానాశ్రయం ఏది?
# Answer: విల్ రోజర్స్ ప్రపంచ విమానాశ్రయం
# Start position: 69
# Neighboring characters: 69: వ 70: ి 71: ల 72: ్ 73:  74: ర 75: ో 76: జ 77: ర 78: ్ 79: స 80: ్
# Context snippet: ాయి, విల్ రోజర్స్ ప్రపంచ విమానాశ్రయం మరియ
# -----------------------------------------------
# -----------------------------------------------
# 41. వేటగాడు-సంగ్రాహక :
# Question: తూర్పు విలువల వెలుగులో ఏ ఏర్పాట్లను చూడటం సులభం?
# Plausible Answer: సామాజిక మరియు లైంగిక
# Start position: 43
# Neighboring characters: 43: స 44: ా 45: మ 46: ా 47: జ 48: ి 49: క 50:  51: మ 52: ర 53: ి 54: య
# Context snippet: ించే సామాజిక మరియు లైంగిక ఏర్ప
# -----------------------------------------------
# 42. ఐక్యరాజ్యసమితి _ జనాభా _ నిధి :
# Question: అవగాహన పెంచడానికి మరియు మద్దతు అందించడానికి ఫండ్ ఎక్కడ పనిచేస్తుంది?
# Answer: అభివృద్ధి చెందుతున్న దేశాలకు
# Start position: 241
# Neighboring characters: 241: అ 242: భ 243: ి 244: వ 245: ృ 246: ద 247: ్ 248: ధ 249: ి 250:  251: చ 252: ె
# Context snippet: డంలో అభివృద్ధి చెందుతున్న దేశాలకు సహాయ
# -----------------------------------------------
# -----------------------------------------------
# 43. రష్యన్ _ సోవియట్ _ ఫెడరేటివ్ _ సోషలిస్ట్ _ రిపబ్లిక్ :
# Question: 1936 నాటి సోవియట్ రాజ్యాంగం రష్యా పరిమాణంపై ఎలాంటి ప్రభావం చూపింది?
# Answer: తగ్గింది.
# Start position: 265
# Neighboring characters: 265: త 266: గ 267: ్ 268: గ 269: ి 270: ం 271: ద 272: ి 273: . 274:  275: క 276: జ
# Context snippet: యంగా తగ్గింది. కజఖ్
# -----------------------------------------------
# -----------------------------------------------
# 44. అలెగ్జాండర్ _ గ్రాహం _ బెల్ :
# Question: బెల్ వ్యక్తిగత పత్రాలను ఏమని పిలుస్తారు?
# Answer: డివిజన్ (అలెగ్జాండర్ గ్రాహం బెల్ ఫ్యామిలీ
# Start position: 159
# Neighboring characters: 159: డ 160: ి 161: వ 162: ి 163: జ 164: న 165: ్ 166:  167: ( 168: అ 169: ల 170: ె
# Context snippet: ప్ట్ డివిజన్ (అలెగ్జాండర్ గ్రాహం బెల్ ఫ్యామిలీ పేపర
# -----------------------------------------------
# -----------------------------------------------
# 45. పబ్ :
# Question: జాన్ షేక్స్పియర్ వృత్తి ఏమిటి?
# Answer: ఇన్స్పెక్టర్లు,
# Start position: 304
# Neighboring characters: 304: ఇ 305: న 306: ్ 307: స 308: ్ 309: ప 310: ె 311: క 312: ్ 313: ట 314: ర 315: ్
# Context snippet: ించే ఇన్స్పెక్టర్లు, బరో
# -----------------------------------------------
# -----------------------------------------------
# 46. ఇంటర్నెట్ _ సర్వీస్ _ ప్రొవైడర్ :
# Question: సోనెట్ అంటే ఏమిటి?
# Answer: సింక్రోనస్ ఆప్టికల్ నెట్వర్కింగ్
# Start position: 303
# Neighboring characters: 303: స 304: ి 305: ం 306: క 307: ్ 308: ర 309: ో 310: న 311: స 312: ్ 313:  314: ఆ
# Context snippet: రియు సింక్రోనస్ ఆప్టికల్ నెట్వర్కింగ్ (SON
# -----------------------------------------------
# -----------------------------------------------
# 47. కామిక్స్ :
# Question: కొంతమంది నిపుణులు కామిక్స్ ఏ రెండు విషయాల కలయిక అని నమ్ముతారు?
# Answer: చిత్రాలు మరియు వచనాల
# Start position: 620
# Neighboring characters: 620: చ 621: ి 622: త 623: ్ 624: ర 625: ా 626: ల 627: ు 628:  629: మ 630: ర 631: ి
# Context snippet: ందరు చిత్రాలు మరియు వచనాల కలయి
# -----------------------------------------------
# -----------------------------------------------
# 48. సెయింట్ _ హెలెనా :
# Question: ఈ ద్వీపం ఎప్పుడు సుసంపన్నమైన కాలాన్ని అనుభవించడం ప్రారంభించింది?
# Answer: 1770
# Start position: 302
# Neighboring characters: 302: 1 303: 7 304: 7 305: 0 306:  307: న 308: ు 309: ం 310: డ 311: ి 312: , 313:
# Context snippet: మారు 1770 నుండ
# -----------------------------------------------
# -----------------------------------------------
# 49. ఆశాజనకమైన హల్లులు (_ c) :
# Question: వాక్యాలు దేనితో వేరు చేయబడతాయి?
# Plausible Answer: అవి ఒకటి లేదా మరొకటి కలిగి
# Start position: 295
# Neighboring characters: 295: అ 296: వ 297: ి 298:  299: ఒ 300: క 301: ట 302: ి 303:  304: ల 305: ే 306: ద
# Context snippet: రియు అవి ఒకటి లేదా మరొకటి కలిగి ఉన్న
# -----------------------------------------------
# 50. హైడ్రోజన్ :
# Question: లోహంతో కలిపినప్పుడు హైడ్రోజన్ ఏ రకమైన ఛార్జ్ తీసుకుంటుంది?
# Answer: ప్రతికూల
# Start position: 636
# Neighboring characters: 636: ప 637: ్ 638: ర 639: త 640: ి 641: క 642: ూ 643: ల 644:  645: ప 646: ా 647: క
# Context snippet:  అవి ప్రతికూల పాక్
# -----------------------------------------------
# -----------------------------------------------
# 51. స్పేస్ రేస్ (_ R) :
# Question: సైన్యం యొక్క కొత్త రెడ్స్టోన్ ఆర్సెనల్ ఏ నగరం మరియు రాష్ట్రంలో ఉంది?
# Answer: అలబామాలోని హంట్స్విల్లేలో
# Start position: 444
# Neighboring characters: 444: అ 445: ల 446: బ 447: ా 448: మ 449: ా 450: ల 451: ో 452: న 453: ి 454:  455: హ
# Context snippet: 50లో అలబామాలోని హంట్స్విల్లేలో ఉన్న
# -----------------------------------------------
# -----------------------------------------------
# 52. వెబ్ బ్రౌజర్ (_ b) :
# Question: ఈ రంగంలోకి ప్రవేశించిన సరికొత్త బ్రౌజర్ ఏది?
# Answer: క్రోమ్
# Start position: 50
# Neighboring characters: 50: క 51: ్ 52: ర 53: ో 54: మ 55: ్ 56: , 57:  58: ఇ 59: ద 60: ి 61:
# Context snippet: ినది క్రోమ్, ఇది
# -----------------------------------------------
# -----------------------------------------------
# 53. బీడౌ _ నావిగేషన్ _ శాటిలైట్ _ సిస్టమ్ :
# Question: ఈ వ్యవస్థ కోసం ప్రయోగించిన మూడవ జలాంతర్గామి పేరు ఏమిటి?
# Plausible Answer: బీడౌ-1సి
# Start position: 124
# Neighboring characters: 124: బ 125: ీ 126: డ 127: ౌ 128: - 129: 1 130: స 131: ి 132:  133: ( 134: బ 135: ్
# Context snippet: రహం, బీడౌ-1సి (బ్య
# -----------------------------------------------
# 54. కానన్ చట్టం (_ l) :
# Question: ఏ సమూహం రోమన్ నియమాలతో సమస్యను తీసుకుంది?
# Answer: ప్రెస్బిటేరియన్లు
# Start position: 22
# Neighboring characters: 22: ప 23: ్ 24: ర 25: ె 26: స 27: ్ 28: బ 29: ి 30: ట 31: ే 32: ర 33: ి
# Context snippet: న్ని ప్రెస్బిటేరియన్లు 1572
# -----------------------------------------------
# -----------------------------------------------
# 55. కమ్యూనికేషన్స్ _ ఇన్ _ సోమాలియా :
# Question: వైర్లెస్ సేవలను ఎవరు ఉపయోగించలేదు?
# Plausible Answer: విద్యా సంస్థలు, కార్పొరేషన్లు మరియు UN, ఎన్జిఓ మరియు దౌత్య కార్యకలాపాలు.
# Start position: 306
# Neighboring characters: 306: వ 307: ి 308: ద 309: ్ 310: య 311: ా 312:  313: స 314: ం 315: స 316: ్ 317: థ
# Context snippet: కులు విద్యా సంస్థలు, కార్పొరేషన్లు మరియు UN, ఎన్జిఓ మరియు దౌత్య కార్యకలాపాలు. మొగా
# -----------------------------------------------
# 56. కాటలాన్ భాష (_ L) :
# Question: కాటలాన్ ఎక్కడ ఓడిపోయింది?
# Answer: స్పానిష్ వారసత్వ యుద్ధంలో
# Start position: 52
# Neighboring characters: 52: స 53: ్ 54: ప 55: ా 56: న 57: ి 58: ష 59: ్ 60:  61: వ 62: ా 63: ర
# Context snippet: ంది. స్పానిష్ వారసత్వ యుద్ధంలో (171
# -----------------------------------------------
# -----------------------------------------------
# 57. బోస్టన్ :
# Question: మేయర్కు ఎలాంటి అధికారం ఉంటుంది?
# Answer: విస్తృతమైన కార్యనిర్వాహక అధికారాన్ని
# Start position: 115
# Neighboring characters: 115: వ 116: ి 117: స 118: ్ 119: త 120: ృ 121: త 122: మ 123: ై 124: న 125:  126: క
# Context snippet: ారు) విస్తృతమైన కార్యనిర్వాహక అధికారాన్ని కలిగ
# -----------------------------------------------
# -----------------------------------------------
# 58. యూనివర్సల్ స్టూడియోస్ (_ S) :
# Question: 1990లో మాట్సుషితా ఎలక్ట్రిక్ పేరు మార్చబడింది?
# Plausible Answer: పానాసోనిక్
# Start position: 200
# Neighboring characters: 200: ప 201: ా 202: న 203: ా 204: స 205: ో 206: న 207: ి 208: క 209: ్ 210:  211: అ
# Context snippet: పుడు పానాసోనిక్ అని
# -----------------------------------------------
# 59. ఎస్టోనియన్ భాష (_ L) :
# Question: ఏ వ్యవస్థ నుండి విలక్షణమైన భవిష్యత్ కాలం లోపిస్తుంది?
# Answer: శబ్ద వ్యవస్థలో
# Start position: 0
# Neighboring characters: 0: శ 1: బ 2: ్ 3: ద 4:  5: వ 6: ్ 7: య 8: వ 9: స 10: ్ 11: థ
# Context snippet: శబ్ద వ్యవస్థలో విలక
# -----------------------------------------------
# -----------------------------------------------
# 60. కాగితం :
# Question: మందంతో పాటు, ఐరోపాలో రీమ్ బరువును పేర్కొనడంలో ఏ లక్షణం ఉపయోగించబడుతుంది?
# Answer: కొలతలు
# Start position: 328
# Neighboring characters: 328: క 329: ొ 330: ల 331: త 332: ల 333: ు 334:  335: మ 336: ర 337: ి 338: య 339: ు
# Context snippet: ొక్క కొలతలు మరియ
# -----------------------------------------------
# -----------------------------------------------
# 61. వయోజన _ సమకాలీన _ సంగీతం :
# Question: గతంలో ఉన్న ఫార్మాట్ పై ఒత్తిడి కారణంగా పట్టణ వయోజన సమకాలీన సంగీతం ఉనికిలోకి వచ్చింది.
# Answer: హాట్ ఎసి
# Start position: 0
# Neighboring characters: 0: హ 1: ా 2: ట 3: ్ 4:  5: ఎ 6: స 7: ి 8:  9: మ 10: ీ 11: ద
# Context snippet: హాట్ ఎసి మీద
# -----------------------------------------------
# -----------------------------------------------
# 62. పగటి వెలుతురు పొదుపు సమయం (_ s) :
# Question: సస్కట్చేవాన్లోని సస్కాటూన్ సగటు సౌర సమయం కంటే ఎన్ని నిమిషాలు ముందు ఉంటుంది?
# Answer: 67
# Start position: 458
# Neighboring characters: 458: 6 459: 7 460:  461: న 462: ి 463: మ 464: ి 465: ష 466: ా 467: ల 468:  469: మ
# Context snippet: నికి 67 నిమి
# -----------------------------------------------
# -----------------------------------------------
# 63. రాయల్ _ ఇన్స్టిట్యూట్ _ ఆఫ్ _ బ్రిటిష్ _ ఆర్కిటెక్ట్స్ :
# Question: స్టీఫెన్ లారెన్స్ బహుమతిని అందుకునే ప్రాజెక్టులకు ఎంత ఖర్చు చేయవచ్చనే పరిమితి ఎంత?
# Answer: మరియు 500,000 పౌండ్ల
# Start position: 144
# Neighboring characters: 144: మ 145: ర 146: ి 147: య 148: ు 149:  150: 5 151: 0 152: 0 153: , 154: 0 155: 0
# Context snippet: ది), మరియు 500,000 పౌండ్ల కంటే
# -----------------------------------------------
# -----------------------------------------------
# 64. నేషనల్ _ ఆర్కైవ్స్ _ అండ్ _ రికార్డ్స్ _ అడ్మినిస్ట్రేషన్ :
# Question: ఎన్హెచ్పిఆర్సి ఎన్ని గ్రాంట్లను ప్రదానం చేసింది?
# Answer: 4,500
# Start position: 363
# Neighboring characters: 363: 4 364: , 365: 5 366: 0 367: 0 368:  369: గ 370: ్ 371: ర 372: ా 373: ం 374: ట
# Context snippet: మారు 4,500 గ్రా
# -----------------------------------------------
# -----------------------------------------------
# 65. ట్రిస్టాన్ _ డా _ కున్హా :
# Question: తుఫాను తరువాత ఈ ప్రాంతానికి పశువులను ఎవరు అందించారు?
# Plausible Answer: బ్రిటిష్ ప్రభుత్వం
# Start position: 207
# Neighboring characters: 207: బ 208: ్ 209: ర 210: ి 211: ట 212: ి 213: ష 214: ్ 215:  216: ప 217: ్ 218: ర
# Context snippet:  ఇది బ్రిటిష్ ప్రభుత్వం అంది
# -----------------------------------------------
# 66. యూనివర్శిటీ _ ఆఫ్ _ కాన్సాస్ :
# Question: కేయూ ప్రత్యేక వృత్తిపరమైన పాఠశాలల్లో ఎంత వసూలు చేస్తారు?
# Answer: అదనపు ఛార్జీలు.
# Start position: 718
# Neighboring characters: 718: అ 719: ద 720: న 721: ప 722: ు 723:  724: ఛ 725: ా 726: ర 727: ్ 728: జ 729: ీ
# Context snippet: రియు అదనపు ఛార్జీలు.
# -----------------------------------------------
# -----------------------------------------------
# 67. నాన్జింగ్ :
# Question: 2014 యూత్ ఒలింపిక్ గేమ్స్ ఎప్పుడు జరిగాయి?
# Answer: ఆగస్టు 16 నుండి 28 వరకు
# Start position: 301
# Neighboring characters: 301: ఆ 302: గ 303: స 304: ్ 305: ట 306: ు 307:  308: 1 309: 6 310:  311: న 312: ు
# Context snippet: రియు ఆగస్టు 16 నుండి 28 వరకు జరిగ
# -----------------------------------------------
# -----------------------------------------------
# 68. అరేనా _ ఫుట్బాల్ _ లీగ్ :
# Question: జెర్రీ కుర్జ్ తరువాత ఎఎఫ్ఎల్ కమిషనర్ ఎవరు అయ్యారు?
# Answer: స్కాట్ బుటెరాను
# Start position: 140
# Neighboring characters: 140: స 141: ్ 142: క 143: ా 144: ట 145: ్ 146:  147: బ 148: ు 149: ట 150: ె 151: ర
# Context snippet: సిఇఒ స్కాట్ బుటెరాను అతని
# -----------------------------------------------
# -----------------------------------------------
# 69. మాండలికం :
# Question: ప్రామాణిక భాషకు సంబంధించి ఒక మాండలికం ఎలా నిలుస్తుంది?
# Answer: ప్రామాణిక భాషకు లోబడి
# Start position: 473
# Neighboring characters: 473: ప 474: ్ 475: ర 476: ా 477: మ 478: ా 479: ణ 480: ి 481: క 482:  483: భ 484: ా
# Context snippet: తలో, ప్రామాణిక భాషకు లోబడి ఉన్న
# -----------------------------------------------
# -----------------------------------------------
# 70. బెర్న్ :
# Question: 2000లో బెర్న్లోని అపార్ట్మెంట్ గృహాలలో ఎంత శాతం ఆక్రమించబడ్డాయి?
# Answer: 90.6%)
# Start position: 292
# Neighboring characters: 292: 9 293: 0 294: . 295: 6 296: % 297: ) 298:  299: శ 300: ా 301: శ 302: ్ 303: వ
# Context snippet: ొక్క 90.6%) శాశ్
# -----------------------------------------------
# -----------------------------------------------
# 71. వెస్ట్ మినిస్టర్ _ అబ్బే :
# Question: 1872లో చాప్టర్ హౌస్ను ఎవరు నాశనం చేశారు?
# Plausible Answer: సర్ జార్జ్ గిల్బర్ట్ స్కాట్
# Start position: 129
# Neighboring characters: 129: స 130: ర 131: ్ 132:  133: జ 134: ా 135: ర 136: ్ 137: జ 138: ్ 139:  140: గ
# Context snippet: 72లో సర్ జార్జ్ గిల్బర్ట్ స్కాట్ పునర
# -----------------------------------------------
# 72. రాజకీయ _ అవినీతి :
# Question: స్థానిక ప్రభుత్వం యొక్క అత్యల్ప రూపం నుండి తగినంతగా సేవలను అందించగల ప్రభుత్వ సేవను అందించడం అంటే ఏమిటి?
# Answer: సబ్సిడీ సూత్రం
# Start position: 21
# Neighboring characters: 21: స 22: బ 23: ్ 24: స 25: ి 26: డ 27: ీ 28:  29: స 30: ూ 31: త 32: ్
# Context snippet: ్లో, సబ్సిడీ సూత్రం వర్త
# -----------------------------------------------
# -----------------------------------------------
# 73. శాస్త్రీయ సంగీతం (_ m) :
# Question: నియోక్లాసికల్ కూర్పులు ఏ శతాబ్దంలో వ్రాయబడ్డాయి?
# Answer: 20వ శతాబ్దం
# Start position: 58
# Neighboring characters: 58: 2 59: 0 60: వ 61:  62: శ 63: త 64: ా 65: బ 66: ్ 67: ద 68: ం 69:
# Context snippet: బడిన 20వ శతాబ్దం లేదా
# -----------------------------------------------
# -----------------------------------------------
# 74. స్లావ్స్ :
# Question: జోర్డాన్స్ ఎక్కడ నుండి వచ్చింది?
# Plausible Answer: సిజేరియా,
# Start position: 188
# Neighboring characters: 188: స 189: ి 190: జ 191: ే 192: ర 193: ి 194: య 195: ా 196: , 197:  198: జ 199: ో
# Context snippet:  ఆఫ్ సిజేరియా, జోర్
# -----------------------------------------------
# 75. సౌతాంప్టన్ :
# Question: సౌతాంప్టన్ విశ్వవిద్యాలయం ఏ సంవత్సరంలో స్థాపించబడింది?
# Answer: 1862లో
# Start position: 31
# Neighboring characters: 31: 1 32: 8 33: 6 34: 2 35: ల 36: ో 37:  38: స 39: ్ 40: థ 41: ా 42: ప
# Context snippet:  ఇది 1862లో స్థా
# -----------------------------------------------
# -----------------------------------------------
# 76. ఒప్పందం :
# Question: దాని పార్టీల నిర్వచించిన సంబంధాలను గుర్తించే ఒక ఉత్సవ సందర్భం యొక్క వస్తునిష్ఠ ఫలితం ఏమిటి?
# Answer: ఒక ఒప్పందం
# Start position: 114
# Neighboring characters: 114: ఒ 115: క 116:  117: ఒ 118: ప 119: ్ 120: ప 121: ం 122: ద 123: ం 124:  125: అ
# Context snippet: ందం. ఒక ఒప్పందం అనేద
# -----------------------------------------------
# -----------------------------------------------
# 77. జోసిప్ _ బ్రోజ్ _ టిటో :
# Question: 1941లో ప్రభుత్వం మరియు సైనిక ప్రతినిధులు జర్మన్ అధికారులను ఎక్కడ కలిశారు?
# Answer: బెల్గ్రేడ్లోని
# Start position: 535
# Neighboring characters: 535: బ 536: ె 537: ల 538: ్ 539: గ 540: ్ 541: ర 542: ే 543: డ 544: ్ 545: ల 546: ో
# Context snippet: ధులు బెల్గ్రేడ్లోని జర్మ
# -----------------------------------------------
# -----------------------------------------------
# 78. మార్షల్ దీవులు (_ I) :
# Question: ఏ సంవత్సరంలో యునైటెడ్ స్టేట్స్ మార్షల్స్ను ఆక్రమించింది?
# Answer: 1944లో
# Start position: 89
# Neighboring characters: 89: 1 90: 9 91: 4 92: 4 93: ల 94: ో 95:  96: ద 97: ్ 98: వ 99: ీ 100: ప
# Context snippet: ంలో, 1944లో ద్వీ
# -----------------------------------------------
# -----------------------------------------------
# 79. స్జ్లాచ్టా :
# Question: గొప్పతనాన్ని సాధించడానికి ఒక వ్యక్తి ఏమి చేస్తాడు?
# Answer: రాష్ట్రానికి ప్రత్యేక సేవలకు
# Start position: 113
# Neighboring characters: 113: ర 114: ా 115: ష 116: ్ 117: ట 118: ్ 119: ర 120: ా 121: న 122: ి 123: క 124: ి
# Context snippet: యినా రాష్ట్రానికి ప్రత్యేక సేవలకు గౌరవ
# -----------------------------------------------
# -----------------------------------------------
# 80. వర్జిల్ :
# Question: ఏ కాలంలో విర్గిల్ కీర్తి అతన్ని మేజిక్ మరియు ప్రవచనాలతో అనుబంధించే పురాణాలను ప్రేరేపించింది?
# Answer: మధ్య యుగాలలో,
# Start position: 0
# Neighboring characters: 0: మ 1: ధ 2: ్ 3: య 4:  5: య 6: ు 7: గ 8: ా 9: ల 10: ల 11: ో
# Context snippet: మధ్య యుగాలలో, విర్
# -----------------------------------------------
# -----------------------------------------------
# 81. ఆల్ప్స్ :
# Question: ట్రయాసిక్, జురాసిక్ మరియు క్రెటేషియస్ కాలాలలో వివిధ పాలియోగ్రఫిక్ ప్రాంతాలకు కారణం ఏమిటి?
# Answer: టెక్టోనిక్ సంఘటనలు వివిధ
# Start position: 223
# Neighboring characters: 223: ట 224: ె 225: క 226: ్ 227: ట 228: ో 229: న 230: ి 231: క 232: ్ 233:  234: స
# Context snippet: వరుస టెక్టోనిక్ సంఘటనలు వివిధ పాలి
# -----------------------------------------------
# -----------------------------------------------
# 82. జీన్ :
# Question: ఎన్హాన్సర్లు ట్రాన్స్క్రిప్షన్ను ఎలా పెంచుతాయి?
# Answer: యాక్టివేటర్ ప్రోటీన్ను బంధించడం ద్వారా
# Start position: 328
# Neighboring characters: 328: య 329: ా 330: క 331: ్ 332: ట 333: ి 334: వ 335: ే 336: ట 337: ర 338: ్ 339:
# Context snippet: ర్లు యాక్టివేటర్ ప్రోటీన్ను బంధించడం ద్వారా ట్రా
# -----------------------------------------------
# -----------------------------------------------
# 83. గినియా-బిసావు :
# Question: గినియా-బిసావులో ఎత్తైన ప్రదేశం ఎంత ఎత్తులో ఉంది?
# Answer: 300 మీటర్లు (984 అడుగులు).
# Start position: 152
# Neighboring characters: 152: 3 153: 0 154: 0 155:  156: మ 157: ీ 158: ట 159: ర 160: ్ 161: ల 162: ు 163:
# Context snippet: దేశం 300 మీటర్లు (984 అడుగులు). గిని
# -----------------------------------------------
# -----------------------------------------------
# 84. జాబితా _ ఆఫ్ _ నంబర్డ్ _ స్ట్రీట్స్ _ ఇన్ _ మన్హట్టన్ :
# Question: క్లబ్ రో ఏ వీధిలో జరుగుతుంది?
# Answer: 27వ వీధి
# Start position: 0
# Neighboring characters: 0: 2 1: 7 2: వ 3:  4: వ 5: ీ 6: ధ 7: ి 8:  9: అ 10: న 11: ే
# Context snippet: 27వ వీధి అనేద
# -----------------------------------------------
# -----------------------------------------------
# 85. మెదడు. :
# Question: ఎస్. సి. ఎన్. ఆప్టిక్ నరాల నుండి దేని ద్వారా సమాచారాన్ని పొందుతుంది?
# Answer: రెటినోహైపోథాలమిక్ ట్రాక్ట్ (ఆర్హెచ్టి)
# Start position: 556
# Neighboring characters: 556: ర 557: ె 558: ట 559: ి 560: న 561: ో 562: హ 563: ై 564: ప 565: ో 566: థ 567: ా
# Context snippet: ణంగా రెటినోహైపోథాలమిక్ ట్రాక్ట్ (ఆర్హెచ్టి) ద్వా
# -----------------------------------------------
# -----------------------------------------------
# 86. తూర్పు సమీపంలో (_ E) :
# Question: "హిమాలయాలకు మించిన సిథియా" ఎక్కడ ఉంది?
# Answer: ఉత్తరాన
# Start position: 59
# Neighboring characters: 59: ఉ 60: త 61: ్ 62: త 63: ర 64: ా 65: న 66:  67: " 68: హ 69: ి 70: మ
# Context snippet: ంది. ఉత్తరాన "హిమ
# -----------------------------------------------
# -----------------------------------------------
# 87. జెజియాంగ్ :
# Question: ఎక్కడ కీర్తి అనేది ఒక ప్రసిద్ధ సామెతకు దారితీసింది?
# Answer: హాంగ్జౌ
# Start position: 312
# Neighboring characters: 312: హ 313: ా 314: ం 315: గ 316: ్ 317: జ 318: ౌ 319:  320: ( 321: అ 322: ల 323: ా
# Context snippet: ంగా, హాంగ్జౌ (అలా
# -----------------------------------------------
# -----------------------------------------------
# 88. రక్షణ మంత్రిత్వ శాఖ (యునైటెడ్ కింగ్డమ్) :
# Question: సంప్రదాయ బెదిరింపులపై ఆధారపడిన సైనిక వ్యయం ఏది అని కొట్టిపారేశారు?
# Answer: "ప్రచ్ఛన్న యుద్ధ మనస్తత్వం"
# Start position: 115
# Neighboring characters: 115: " 116: ప 117: ్ 118: ర 119: చ 120: ్ 121: ఛ 122: న 123: ్ 124: న 125:  126: య
# Context snippet: ోయిన "ప్రచ్ఛన్న యుద్ధ మనస్తత్వం" ని డ
# -----------------------------------------------
# -----------------------------------------------
# 89. హై-డెఫినిషన్ _ టెలివిజన్ :
# Question: ఐటియు-ఆర్ ఒకే అంతర్జాతీయ డివిడి ప్రమాణాన్ని ఏర్పాటు చేసే దిశగా పనిచేయడం ఎప్పుడు ప్రారంభించింది?
# Plausible Answer: 1983లో,
# Start position: 0
# Neighboring characters: 0: 1 1: 9 2: 8 3: 3 4: ల 5: ో 6: , 7:  8: ఇ 9: ం 10: ట 11: ర
# Context snippet: 1983లో, ఇంటర
# -----------------------------------------------
# 90. చెక్క. :
# Question: వేగంగా పెరిగినప్పుడు ఖచ్చితంగా కఠినంగా మరియు బలంగా ఉండే ఏకైక రకమైన కలప ఏది?
# Answer: రింగ్-పోరస్
# Start position: 346
# Neighboring characters: 346: ర 347: ి 348: ం 349: గ 350: ్ 351: - 352: ప 353: ో 354: ర 355: స 356: ్ 357:
# Context snippet:  ఇతర రింగ్-పోరస్ అడవు
# -----------------------------------------------
# -----------------------------------------------
# 91. సోమాలీలు :
# Question: ఏ ఆసియా దేశం సోమాలి సంస్కృతిని ప్రభావితం చేసింది?
# Answer: భారతదేశం
# Start position: 78
# Neighboring characters: 78: భ 79: ా 80: ర 81: త 82: ద 83: ే 84: శ 85: ం 86:  87: మ 88: ర 89: ి
# Context snippet: ్పం, భారతదేశం మరియ
# -----------------------------------------------
# -----------------------------------------------
# 92. మధ్య యుగాలు (_ A) :
# Question: ఏ శతాబ్దంలో కార్పస్ జురిస్ సివిలిస్ తిరిగి కనుగొనబడింది?
# Answer: 11వ
# Start position: 179
# Neighboring characters: 179: 1 180: 1 181: వ 182:  183: శ 184: త 185: ా 186: బ 187: ్ 188: ద 189: ం 190: ల
# Context snippet: ్టం, 11వ శతాబ
# -----------------------------------------------
# -----------------------------------------------
# 93. ఫోనాలజీ :
# Question: ధ్వని శాస్త్రం గురించి లాస్ ఎప్పుడు రాశారు?
# Answer: (1998)
# Start position: 478
# Neighboring characters: 478: ( 479: 1 480: 9 481: 9 482: 8 483: ) 484:  485: స 486: ్ 487: వ 488: ర 489: శ
# Context snippet: లాస్ (1998) స్వర
# -----------------------------------------------
# -----------------------------------------------
# 94. కంప్యూటర్ :
# Question: దోషాలు సాధారణంగా ఎవరి తప్పు లేదా ఏమిటి?
# Answer: ప్రోగ్రామర్ లోపం లేదా ప్రోగ్రామ్ రూపకల్పనలో చేసిన పర్యవేక్షణ
# Start position: 725
# Neighboring characters: 725: ప 726: ్ 727: ర 728: ో 729: గ 730: ్ 731: ర 732: ా 733: మ 734: ర 735: ్ 736:
# Context snippet: పుడూ ప్రోగ్రామర్ లోపం లేదా ప్రోగ్రామ్ రూపకల్పనలో చేసిన పర్యవేక్షణ ఫలిత
# -----------------------------------------------
# -----------------------------------------------
# 95. నల్ల ప్రజలు (_ p) :
# Question: జనాభా లెక్కల నిర్వచనం దేనికి ఆధారం కాదు?
# Answer: అని, శాస్త్రీయంగా లేదా మానవశాస్త్రపరంగా
# Start position: 373
# Neighboring characters: 373: అ 374: న 375: ి 376: , 377:  378: శ 379: ా 380: స 381: ్ 382: త 383: ్ 384: ర
# Context snippet: ణాలు అని, శాస్త్రీయంగా లేదా మానవశాస్త్రపరంగా అర్థ
# -----------------------------------------------
# -----------------------------------------------
# 96. ది టైమ్స్ (_ T) :
# Question: 1982లో, ది టైమ్స్ యొక్క మునుపటి ఎడిటర్ స్థానంలో వచ్చిన ఎడిటర్ పేరు ఏమిటి?
# Answer: హెరాల్డ్ ఎవాన్స్ను
# Start position: 118
# Neighboring characters: 118: హ 119: ె 120: ర 121: ా 122: ల 123: ్ 124: డ 125: ్ 126:  127: ఎ 128: వ 129: ా
# Context snippet: నంలో హెరాల్డ్ ఎవాన్స్ను నియమ
# -----------------------------------------------
# -----------------------------------------------
# 97. న్యూ ఢిల్లీ (_ D) :
# Question: న్యూఢిల్లీలోని వ్యాపార, ప్రభుత్వ సంస్థలు అధికారిక ప్రయోజనాల కోసం ఏ భాషను ఉపయోగిస్తాయి?
# Answer: ఆంగ్లం
# Start position: 130
# Neighboring characters: 130: ఆ 131: ం 132: గ 133: ్ 134: ల 135: ం 136:  137: ప 138: ్ 139: ర 140: ధ 141: ా
# Context snippet: భాష. ఆంగ్లం ప్రధ
# -----------------------------------------------
# -----------------------------------------------
# 98. పక్షి వలస (_ m) :
# Question: వలసలను అధ్యయనం చేయడానికి పురాతన మార్గం ఏమిటి?
# Answer: మార్కింగ్తో
# Start position: 31
# Neighboring characters: 31: మ 32: ా 33: ర 34: ్ 35: క 36: ి 37: ం 38: గ 39: ్ 40: త 41: ో 42:
# Context snippet: నమైన మార్కింగ్తో సహా
# -----------------------------------------------
# -----------------------------------------------
# 99. అట్లాంటిక్ _ సిటీ, _ న్యూ _ జెర్సీ :
# Question: అట్లాంటిక్ సిటీలో మొదటి బోర్డువాక్ ఏ సంవత్సరంలో నిర్మించబడింది?
# Answer: 1870లో
# Start position: 17
# Neighboring characters: 17: 1 18: 8 19: 7 20: 0 21: ల 22: ో 23:  24: బ 25: ీ 26: చ 27: ్ 28:
# Context snippet: వాక్ 1870లో బీచ్
# -----------------------------------------------
# -----------------------------------------------
# 100. ఇమ్యునాలజీ :
# Question: ఏ గ్రీకు చరిత్రకారుడు ఆ సంజ్ఞామానం చేసాడు?
# Answer: తుసిడైడ్స్
# Start position: 393
# Neighboring characters: 393: త 394: ు 395: స 396: ి 397: డ 398: ై 399: డ 400: ్ 401: స 402: ్ 403:  404: ప
# Context snippet: లరని తుసిడైడ్స్ పేర్
# -----------------------------------------------
# -----------------------------------------------
# 101. MP3 :
# Question: పొర I లేదా II లో కాకుండా పొర III లో మాత్రమే ఏది చేర్చబడింది?
# Answer: ఫిల్టర్ బ్యాంకులో
# Start position: 175
# Neighboring characters: 175: ఫ 176: ి 177: ల 178: ్ 179: ట 180: ర 181: ్ 182:  183: బ 184: ్ 185: య 186: ా
# Context snippet: రిడ్ ఫిల్టర్ బ్యాంకులో భాగం
# -----------------------------------------------
# -----------------------------------------------
# 102. హౌస్ సంగీతం (_ m) :
# Question: UKలో #2 హిట్ అయిన మొదటి హౌస్ సింగిల్ ఏది?
# Plausible Answer: స్టీవ్ "సిల్క్" హర్లీ యొక్క "జాక్ యువర్ బాడీ"
# Start position: 31
# Neighboring characters: 31: స 32: ్ 33: ట 34: ీ 35: వ 36: ్ 37:  38: " 39: స 40: ి 41: ల 42: ్
# Context snippet: రుడు స్టీవ్ "సిల్క్" హర్లీ యొక్క "జాక్ యువర్ బాడీ" UKలో
# -----------------------------------------------
# 103. లెటర్ కేస్ (_ c) :
# Question: లాటిన్, గ్రీకు మరియు సిరిలిక్ మధ్య పంచుకోబడే అనేక సాధారణ అక్షరాలలో ఏది?
# Answer: ఆకారాలు
# Start position: 360
# Neighboring characters: 360: ఆ 361: క 362: ా 363: ర 364: ా 365: ల 366: ు 367:  368: ల 369: ా 370: ట 371: ి
# Context snippet: షరాల ఆకారాలు లాటి
# -----------------------------------------------
# -----------------------------------------------
# 104. చివావా _ (రాష్ట్రం) :
# Question: విల్లా ప్రాణాలను ఎవరు రక్షించారు?
# Answer: రౌల్ మాడెరో
# Start position: 569
# Neighboring characters: 569: ర 570: ౌ 571: ల 572: ్ 573:  574: మ 575: ా 576: డ 577: ె 578: ర 579: ో 580:
# Context snippet: రుడు రౌల్ మాడెరో జోక్
# -----------------------------------------------
# -----------------------------------------------
# 105. ఇమామా (షియా సిద్ధాంతం) :
# Question: షియా ఇస్లాం సిద్ధాంతాన్ని ఏమని పిలుస్తారు?
# Answer: ఇమామాహ్
# Start position: 0
# Neighboring characters: 0: ఇ 1: మ 2: ా 3: మ 4: ా 5: హ 6: ్ 7:  8: ( 9: అ 10: ర 11: బ
# Context snippet: ఇమామాహ్ (అరబ
# -----------------------------------------------
# -----------------------------------------------
# 106. పిచ్ (సంగీతం) :
# Question: లీనియర్ పిచ్లోని ఆక్టేవ్లు ఏ పరిమాణంలో ఉంటాయి?
# Answer: 12
# Start position: 69
# Neighboring characters: 69: 1 70: 2 71:  72: క 73: ల 74: ి 75: గ 76: ి 77:  78: ఉ 79: ం 80: ట
# Context snippet: మాణం 12 కలిగ
# -----------------------------------------------
# -----------------------------------------------
# 107. ఇంగ్లాండ్ _ జాతీయ _ ఫుట్బాల్ _ జట్టు :
# Question: మేనేజర్ స్వెన్-గోరాన్ ఎరిక్సన్ పదవీకాలంలో ఎన్ని పోటీ మ్యాచ్లు ఓడిపోయారు?
# Answer: ఐదు
# Start position: 390
# Neighboring characters: 390: ఐ 391: ద 392: ు 393:  394: ప 395: ో 396: ట 397: ీ 398:  399: మ 400: ్ 401: య
# Context snippet: ేవలం ఐదు పోటీ
# -----------------------------------------------
# -----------------------------------------------
# 108. హ్యూస్టన్ :
# Question: రెడ్ లైన్ రైలు మార్గం ఎక్కడ ముగిసింది?
# Answer: ఎన్ఆర్జీ పార్క్
# Start position: 100
# Neighboring characters: 100: ఎ 101: న 102: ్ 103: ఆ 104: ర 105: ్ 106: జ 107: ీ 108:  109: ప 110: ా 111: ర
# Context snippet: ించి ఎన్ఆర్జీ పార్క్ వద్ద
# -----------------------------------------------
# -----------------------------------------------
# 109. రాగి. :
# Question: అతిపెద్ద రాగి ఆవిష్కరణ ఎంత పెద్దది?
# Answer: 420 టన్నుల
# Start position: 301
# Neighboring characters: 301: 4 302: 2 303: 0 304:  305: ట 306: న 307: ్ 308: న 309: ు 310: ల 311:  312: బ
# Context snippet: ంది. 420 టన్నుల బరువ
# -----------------------------------------------
# -----------------------------------------------
# 110. గుర్తింపు _ (సామాజిక _ శాస్త్రం) :
# Question: మార్కర్లను ఇతరులపై ఏమి చేయటానికి ఉపయోగించవచ్చు?
# Answer: ప్రభావం
# Start position: 461
# Neighboring characters: 461: ప 462: ్ 463: ర 464: భ 465: ా 466: వ 467: ం 468:  469: ఇ 470: త 471: ర 472:
# Context snippet: దీని ప్రభావం ఇతర
# -----------------------------------------------
# -----------------------------------------------
# 111. హిమాచల్ _ ప్రదేశ్ :
# Question: భారత రాష్ట్రపతి ఎవరిని ముఖ్యమంత్రిగా నియమిస్తారు?
# Plausible Answer: శాసనసభలో మెజారిటీ ఉన్న పార్టీ లేదా సంకీర్ణ నాయకుడిని
# Start position: 649
# Neighboring characters: 649: శ 650: ా 651: స 652: న 653: స 654: భ 655: ల 656: ో 657:  658: మ 659: ె 660: జ
# Context snippet: పతి. శాసనసభలో మెజారిటీ ఉన్న పార్టీ లేదా సంకీర్ణ నాయకుడిని గవర్
# -----------------------------------------------
# 112. కమ్యూనికేషన్ :
# Question: కమ్యూనికేషన్ కోసం మొదటి నమూనా ఏది కలిగి ఉంది?
# Answer: పంపినవారు, ఛానెల్ మరియు రిసీవర్.
# Start position: 267
# Neighboring characters: 267: ప 268: ం 269: ప 270: ి 271: న 272: వ 273: ా 274: ర 275: ు 276: , 277:  278: ఛ
# Context snippet: ాయిః పంపినవారు, ఛానెల్ మరియు రిసీవర్. పంపి
# -----------------------------------------------
# -----------------------------------------------
# 113. ద్రాక్ష. :
# Question: తెలుపు ద్రాక్ష ఏ రంగులో ఉంటుంది?
# Answer: ఆకుపచ్చ
# Start position: 175
# Neighboring characters: 175: ఆ 176: క 177: ు 178: ప 179: చ 180: ్ 181: చ 182:  183: ర 184: ం 185: గ 186: ు
# Context snippet: నికి ఆకుపచ్చ రంగు
# -----------------------------------------------
# -----------------------------------------------
# 114. కంప్యూటర్ భద్రత (_ S) :
# Question: హార్డ్వేర్కు భౌతిక ప్రాప్యతను నియంత్రించే అభ్యాసం ఏమిటి?
# Answer: కంప్యూటర్ భద్రత,
# Start position: 0
# Neighboring characters: 0: క 1: ం 2: ప 3: ్ 4: య 5: ూ 6: ట 7: ర 8: ్ 9:  10: భ 11: ద
# Context snippet: కంప్యూటర్ భద్రత, సైబర
# -----------------------------------------------
# -----------------------------------------------
# 115. ఆర్థడాక్స్ _ జుడాయిజం :
# Question: ఆర్థడాక్స్ పురుషులు ఇంటి లోపల ఉన్నప్పుడు ఏమి ధరించరు?
# Plausible Answer: టోపీలు మరియు సూట్లను
# Start position: 493
# Neighboring characters: 493: ట 494: ో 495: ప 496: ీ 497: ల 498: ు 499:  500: మ 501: ర 502: ి 503: య 504: ు
# Context snippet: నల్ల టోపీలు మరియు సూట్లను ధరిస
# -----------------------------------------------
# 116. జంతువు. :
# Question: యూకారియోటిక్ కణాల చుట్టూ ఉన్న ఎక్స్ట్రాసెల్యులర్ మ్యాట్రిక్స్ దేనితో తయారు చేయబడింది?
# Answer: కొల్లాజెన్ మరియు సాగే గ్లైకోప్రొటీన్లతో
# Start position: 61
# Neighboring characters: 61: క 62: ొ 63: ల 64: ్ 65: ల 66: ా 67: జ 68: ె 69: న 70: ్ 71:  72: మ
# Context snippet: ట్టూ కొల్లాజెన్ మరియు సాగే గ్లైకోప్రొటీన్లతో కూడి
# -----------------------------------------------
# -----------------------------------------------
# 117. బీర్. :
# Question: మాల్టెడ్ బార్లీని వేడి నీటిలో కలిపినప్పుడు తయారీకి మొదటి దశ ఏమిటి?
# Answer: మాషింగ్
# Start position: 98
# Neighboring characters: 98: మ 99: ా 100: ష 101: ి 102: ం 103: గ 104: ్ 105: " 106:  107: అ 108: న 109: ి
# Context snippet: శను "మాషింగ్" అని
# -----------------------------------------------
# -----------------------------------------------
# 118. జాతి _ మరియు _ జాతి _ లో _ యునైటెడ్ _ స్టేట్స్ _ జనాభా గణన :
# Question: 1997లో జాతి మరియు జాతిపై వారి పునర్విమర్శతో OMB ఏమి అందించాలని ఆశించింది?
# Answer: స్థిరమైన డేటాను
# Start position: 180
# Neighboring characters: 180: స 181: ్ 182: థ 183: ి 184: ర 185: మ 186: ై 187: న 188:  189: డ 190: ే 191: ట
# Context snippet: తిపై స్థిరమైన డేటాను అంది
# -----------------------------------------------
# -----------------------------------------------
# 119. యునైటెడ్ _ స్టేట్స్ _ డాలర్ :
# Question: "మొత్తం" అనే పదాన్ని ఏ శతాబ్దంలో కనుగొనవచ్చు?
# Plausible Answer: 18వ
# Start position: 173
# Neighboring characters: 173: 1 174: 8 175: వ 176:  177: శ 178: త 179: ా 180: బ 181: ్ 182: ద 183: ా 184: న
# Context snippet: ంది. 18వ శతాబ
# -----------------------------------------------
# 120. ఇంపీరియల్ _ కాలేజ్ _ లండన్ :
# Question: ఆర్ఈఎఫ్ అంచనా కోసం ఇంపీరియల్ ఎంత మంది సిబ్బంది అంచనాలను సమర్పించారు?
# Answer: 1,257
# Start position: 93
# Neighboring characters: 93: 1 94: , 95: 2 96: 5 97: 7 98:  99: మ 100: ం 101: ద 102: ి 103:  104: స
# Context snippet: త్తం 1,257 మంది
# -----------------------------------------------
# -----------------------------------------------
# 121. హనోవర్ :
# Question: VLW అంటే ఏమిటి?
# Answer: యునైటెడ్ లైట్ మెటల్ వర్క్స్
# Start position: 350
# Neighboring characters: 350: య 351: ు 352: న 353: ై 354: ట 355: ె 356: డ 357: ్ 358:  359: ల 360: ై 361: ట
# Context snippet: లోని యునైటెడ్ లైట్ మెటల్ వర్క్స్ (VLW
# -----------------------------------------------
# -----------------------------------------------
# 122. భావోద్వేగం. :
# Question: పెరిగిన చెమటతో పాటు, భావోద్వేగాలకు సంబంధించిన శారీరక మార్పు ఏమిటి?
# Answer: పల్స్ రేటులో మార్పులు),
# Start position: 186
# Neighboring characters: 186: ప 187: ల 188: ్ 189: స 190: ్ 191:  192: ర 193: ే 194: ట 195: ు 196: ల 197: ో
# Context snippet: ెమట, పల్స్ రేటులో మార్పులు), వ్యక
# -----------------------------------------------
# -----------------------------------------------
# 123. Everton_F.C. :
# Question: ఎవర్టన్ ఫ్యాన్ సైట్లో కొత్త చిహ్నం గురించి మొత్తం ఎన్ని ఓట్లు ఉన్నాయి?
# Plausible Answer: 22,000
# Start position: 613
# Neighboring characters: 613: 2 614: 2 615: , 616: 0 617: 0 618: 0 619:  620: స 621: ం 622: త 623: క 624: ా
# Context snippet: ిషన్ 22,000 సంతక
# -----------------------------------------------
# 124. పాత ఆంగ్లం (_ I) :
# Question: పాత ఆంగ్లం ఏ భాష నుండి కొన్ని పదాలను స్వీకరించింది?
# Answer: లాటిన్
# Start position: 13
# Neighboring characters: 13: ల 14: ా 15: ట 16: ి 17: న 18: ్ 19:  20: న 21: ు 22: ం 23: డ 24: ి
# Context snippet: లంలో లాటిన్ నుండ
# -----------------------------------------------
# -----------------------------------------------
# 125. విమాన వాహక నౌక (_ c) :
# Question: ఎగుమతి వాహకాలు ఏ ప్రయోజనం కోసం అభివృద్ధి చేయబడ్డాయి?
# Plausible Answer: నౌకల కాన్వాయ్లకు రక్షణను అందించడానికి
# Start position: 203
# Neighboring characters: 203: న 204: ౌ 205: క 206: ల 207:  208: క 209: ా 210: న 211: ్ 212: వ 213: ా 214: య
# Context snippet: ర్లు నౌకల కాన్వాయ్లకు రక్షణను అందించడానికి అభివ
# -----------------------------------------------
# 126. ఫెడరల్ _ ఏవియేషన్ _ అడ్మినిస్ట్రేషన్ :
# Question: విమానయానం యొక్క పర్యావరణ అంశాలతో మాతృభూమి ఎవరు ఎక్కువ నిమగ్నమయ్యారు?
# Plausible Answer: 1968లో
# Start position: 285
# Neighboring characters: 285: 1 286: 9 287: 6 288: 8 289: ల 290: ో 291:  292: వ 293: ి 294: మ 295: ా 296: న
# Context snippet: ఫ్ఏఏ 1968లో విమా
# -----------------------------------------------
# 127. లాంక్షైర్ :
# Question: లాంక్షైర్ లీగ్ పోటీ ఏ సంవత్సరాల నుండి జరిగింది?
# Answer: 1895 నుండి 1970 వరకు
# Start position: 104
# ...
# Context snippet: పయస్ IX నిర్వచించిన సిద్ధాంతం 12వ
# -----------------------------------------------
# 402. నమీబియా :
# Question: 1999లో నమీబియాలో విద్యార్థి-ఉపాధ్యాయ నిష్పత్తి ఎంత?
# Answer: 32:1 గా
# Start position: 277
# Neighboring characters: 277: 3 278: 2 279: : 280: 1 281:  282: గ 283: ా 284:  285: అ 286: ం 287: చ 288: న
# Context snippet: త్తి 32:1 గా అంచన
# -----------------------------------------------
# -----------------------------------------------
# 403. రష్యన్ భాష (_ L) :
# Question: 20వ శతాబ్దానికి ముందు రష్యన్ ఎవరు మాట్లాడేవారు?
# Answer: ఉన్నత కులీన వర్గాలు మరియు పట్టణ జనాభా
# Start position: 135
# Neighboring characters: 135: ఉ 136: న 137: ్ 138: న 139: త 140:  141: క 142: ు 143: ల 144: ీ 145: న 146:
# Context snippet: రూపం ఉన్నత కులీన వర్గాలు మరియు పట్టణ జనాభా మాత్
# -----------------------------------------------
# -----------------------------------------------
# 404. యునైటెడ్ _ స్టేట్స్ _ ఎయిర్ _ ఫోర్స్ :
# Question: స్నేహపూర్వక దళాలకు సన్నిహితంగా ఉండటానికి ఈ యూఎస్ ఎయిర్ ఫోర్స్ విమానాలకు ఏమి అవసరం?
# Answer: ఖచ్చితమైన దాడులు
# Start position: 231
# Neighboring characters: 231: ఖ 232: చ 233: ్ 234: చ 235: ి 236: త 237: మ 238: ై 239: న 240:  241: ద 242: ా
# Context snippet: ుండి ఖచ్చితమైన దాడులు అవసర
# -----------------------------------------------
# -----------------------------------------------
# 405. లైట్-ఎమిటింగ్ డయోడ్ (_ D) :
# Question: ఎల్ఈడీ అంటే ఏమిటి?
# Answer: డయోడ్లు ఇప్పుడు
# Start position: 283
# Neighboring characters: 283: డ 284: య 285: ో 286: డ 287: ్ 288: ల 289: ు 290:  291: ఇ 292: ప 293: ్ 294: ప
# Context snippet: ింగ్ డయోడ్లు ఇప్పుడు ఏవియ
# -----------------------------------------------
# -----------------------------------------------
# 406. గొప్ప శక్తి (_ P) :
# Question: ప్రస్తుత అంతర్జాతీయ వ్యవస్థ యొక్క పరిధి అంతటా ఏ రకమైన శక్తులు వాస్తవ ప్రభావాన్ని కలిగి ఉండాలి?
# Answer: గొప్ప శక్తి
# Start position: 285
# Neighboring characters: 285: గ 286: ొ 287: ప 288: ్ 289: ప 290:  291: శ 292: క 293: ్ 294: త 295: ి 296:
# Context snippet: ా ఒక గొప్ప శక్తి వాస్
# -----------------------------------------------
# -----------------------------------------------
# 407. పక్షి. :
# Question: శ్వాసకోశ వ్యవస్థకు అనుసంధానించే పెద్ద గాలి నిండిన కుహరాలు ఏమిటి?
# Answer: (వాయు కుహరాలు
# Start position: 109
# Neighboring characters: 109: ( 110: వ 111: ా 112: య 113: ు 114:  115: క 116: ు 117: హ 118: ర 119: ా 120: ల
# Context snippet: ాలను (వాయు కుహరాలు అని
# -----------------------------------------------
# -----------------------------------------------
# 408. క్వింగ్ రాజవంశం (_ d) :
# Question: మంచూరియాను మొదట ఎవరు నడిపారు?
# Answer: సైనిక మరియు
# Start position: 623
# Neighboring characters: 623: స 624: ై 625: న 626: ి 627: క 628:  629: మ 630: ర 631: ి 632: య 633: ు 634:
# Context snippet: ీకృత సైనిక మరియు పరిప
# -----------------------------------------------
# -----------------------------------------------
# 409. అమెరికాలోని స్వదేశీ ప్రజలు :
# Question: యునైటెడ్ స్టేట్స్ జనాభాలో ఏ అమౌన్ స్థానిక అమెరికన్ల విషయంలో రాజీపడింది?
# Answer: <ID1 నుండి 2 శాతం వరకు
# Start position: 50
# Neighboring characters: 50: < 51: I 52: D 53: 1 54:  55: న 56: ు 57: ం 58: డ 59: ి 60:  61: 2
# Context snippet: భాలో <ID1 నుండి 2 శాతం వరకు ఉన్న
# -----------------------------------------------
# -----------------------------------------------
# 410. ఎరుపు. :
# Question: క్రీస్తు మరియు ఏ ఇతర క్రైస్తవ వ్యక్తి మధ్యయుగ చిత్రలేఖనంలో తరచుగా ఎరుపు రంగులో చిత్రించబడ్డారు?
# Answer: వర్జిన్ మేరీ
# Start position: 758
# Neighboring characters: 758: వ 759: ర 760: ్ 761: జ 762: ి 763: న 764: ్ 765:  766: మ 767: ే 768: ర 769: ీ
# Context snippet: రియు వర్జిన్ మేరీ ఇద్ద
# -----------------------------------------------
# -----------------------------------------------
# 411. ఈజిప్ట్ :
# Question: ఈజిప్టు సైన్యాన్ని ఎవరు ఆధునీకరించారు?
# Answer: ముహమ్మద్ అలీ పాషా
# Start position: 0
# Neighboring characters: 0: మ 1: ు 2: హ 3: మ 4: ్ 5: మ 6: ద 7: ్ 8:  9: అ 10: ల 11: ీ
# Context snippet: ముహమ్మద్ అలీ పాషా సైన్
# -----------------------------------------------
# -----------------------------------------------
# 412. మొజాయిక్ :
# Question: పునరుజ్జీవనం యొక్క గొప్ప మొజాయిక్ పని ఎక్కడ ఉంది?
# Answer: కాన్స్టాంటినోపుల్లోని కోరా చర్చి
# Start position: 55
# Neighboring characters: 55: క 56: ా 57: న 58: ్ 59: స 60: ్ 61: ట 62: ా 63: ం 64: ట 65: ి 66: న
# Context snippet:  పని కాన్స్టాంటినోపుల్లోని కోరా చర్చి యొక్
# -----------------------------------------------
# -----------------------------------------------
# 413. విశ్వవిద్యాలయం :
# Question: ఏ వ్యక్తులు సాధారణంగా యూనివర్సిటాస్ కోసం చార్టర్లను ఆమోదించారు?
# Answer: "యువరాజులు, ప్రభువులు
# Start position: 223
# Neighboring characters: 223: " 224: య 225: ు 226: వ 227: ర 228: ా 229: జ 230: ు 231: ల 232: ు 233: , 234:
# Context snippet: కమైన "యువరాజులు, ప్రభువులు లేదా
# -----------------------------------------------
# -----------------------------------------------
# 414. మతం _ పురాతన _ రోమ్లో :
# Question: రోమన్లు ఏ పౌరాణిక వ్యక్తిని పాక్షిక దైవిక వ్యక్తిగా భావించారు?
# Answer: ఎనియాస్
# Start position: 369
# Neighboring characters: 369: ఎ 370: న 371: ి 372: య 373: ా 374: స 375: ్ 376:  377: ఆ 378: శ 379: ్ 380: ర
# Context snippet:  చేత ఎనియాస్ ఆశ్ర
# -----------------------------------------------
# -----------------------------------------------
# 415. యూట్యూబ్ :
# Question: యూట్యూబ్ వినియోగదారులకు కంటెంట్ను ఎక్కడ చూసే అవకాశాన్ని అందిస్తుంది?
# Answer: వారి వెబ్సైట్ వెలుపల
# Start position: 24
# Neighboring characters: 24: వ 25: ా 26: ర 27: ి 28:  29: వ 30: ె 31: బ 32: ్ 33: స 34: ై 35: ట
# Context snippet: ులకు వారి వెబ్సైట్ వెలుపల ఉన్న
# -----------------------------------------------
# -----------------------------------------------
# 416. యునైటెడ్ స్టేట్స్ లో చర్చి మరియు రాష్ట్రాలను వేరు చేయడం :
# Question: బైబిల్ భాగాన్ని దాని నినాదం వలె ఉపయోగించకుండా ఒహియో ఎందుకు అనుమతించబడలేదు?
# Plausible Answer: ఎందుకంటే ఇది ఒక నిర్దిష్ట మతానికి ప్రాధాన్యత ఇవ్వలేదు.
# Start position: 563
# Neighboring characters: 563: ఎ 564: ం 565: ద 566: ు 567: క 568: ం 569: ట 570: ే 571:  572: ఇ 573: ద 574: ి
# Context snippet: మే", ఎందుకంటే ఇది ఒక నిర్దిష్ట మతానికి ప్రాధాన్యత ఇవ్వలేదు.
# -----------------------------------------------
# 417. ప్రొటెస్టెంటిజం :
# Question: ప్రొటెస్టంట్ చర్చిలు ఏ అర్చకత్వ నియమాలను తిరస్కరిస్తాయి?
# Answer: బ్రహ్మచారి
# Start position: 251
# Neighboring characters: 251: బ 252: ్ 253: ర 254: హ 255: ్ 256: మ 257: చ 258: ా 259: ర 260: ి 261:  262: అ
# Context snippet: చిలు బ్రహ్మచారి అర్చ
# -----------------------------------------------
# -----------------------------------------------
# 418. బ్రాస్% C3% ADlia :
# Question: బ్రెసిలియా కేథడ్రల్లో ఎన్ని సారూప్య నిలువు వరుసలు ఉపయోగించబడ్డాయి?
# Answer: 16
# Start position: 494
# Neighboring characters: 494: 1 495: 6 496:  497: స 498: ా 499: ర 500: ూ 501: ప 502: ్ 503: య 504:  505: క
# Context snippet: మాణం 16 సారూ
# -----------------------------------------------
# -----------------------------------------------
# 419. గ్రీస్ యొక్క ఆర్థిక వ్యవస్థ :
# Question: 1999 సూచన సంవత్సరంలో గ్రీస్ బడ్జెట్ లోటు 3 శాతం పరిమితిని ఎంత మించిపోయింది?
# Answer: తద్వారా 3 శాతం
# Start position: 371
# Neighboring characters: 371: త 372: ద 373: ్ 374: వ 375: ా 376: ర 377: ా 378:  379: 3 380:  381: శ 382: ా
# Context snippet: ంది, తద్వారా 3 శాతం పరిమ
# -----------------------------------------------
# -----------------------------------------------
# 420. పార్టీ _ లీడర్ _ ఆఫ్ _ ది _ యునైటెడ్ _ స్టేట్స్ _ హౌస్ _ ఆఫ్ _ రిప్రజెంటేటివ్స్ :
# Question: న్యూట్ గింగ్రిచ్ తరువాత స్పీకర్ గా ఎవరు నియమితులయ్యారు?
# Answer: డెన్నిస్ హెకర్
# Start position: 902
# Neighboring characters: 902: డ 903: ె 904: న 905: ్ 906: న 907: ి 908: స 909: ్ 910:  911: హ 912: ె 913: క
# Context snippet: రికి డెన్నిస్ హెకర్ తన డ
# -----------------------------------------------
# -----------------------------------------------
# 421. అర్మేనియన్లు :
# Question: మొదటి అరబ్ నిర్మాణాలు ఎప్పుడు నిర్మించబడ్డాయి?
# Plausible Answer: 4 వ మరియు 7 వ శతాబ్దం మధ్య
# Start position: 25
# Neighboring characters: 25: 4 26:  27: వ 28:  29: మ 30: ర 31: ి 32: య 33: ు 34:  35: 7 36:
# Context snippet: చిలు 4 వ మరియు 7 వ శతాబ్దం మధ్య నిర్
# -----------------------------------------------
# 422. యెహోవా% 27s _ సాక్షులు :
# Question: ప్రపంచవ్యాప్తంగా ఎంత మంది అనుచరులు ఉన్నారని ఈ బృందం పేర్కొంది?
# Answer: 2.2 మిలియన్లకు పైగా అనుచరుల
# Start position: 165
# Neighboring characters: 165: 2 166: . 167: 2 168:  169: మ 170: ి 171: ల 172: ి 173: య 174: న 175: ్ 176: ల
# Context snippet: ొన్న 2.2 మిలియన్లకు పైగా అనుచరుల ప్రప
# -----------------------------------------------
# -----------------------------------------------
# 423. Dwight_D._Eisenhower :
# Question: ఐసెన్హోవర్ మరణించిన తేదీ ఏమిటి?
# Answer: మార్చి 28,1969
# Start position: 0
# Neighboring characters: 0: మ 1: ా 2: ర 3: ్ 4: చ 5: ి 6:  7: 2 8: 8 9: , 10: 1 11: 9
# Context snippet: మార్చి 28,1969 ఉదయం
# -----------------------------------------------
# -----------------------------------------------
# 424. ది _ బ్రోంక్స్ :
# Question: బ్రోంక్స్లో ఎంత మంది బహుళ జాతి ప్రజలు నివసిస్తున్నారు?
# Answer: ప్రజలు 41,800 మందికి
# Start position: 85
# Neighboring characters: 85: ప 86: ్ 87: ర 88: జ 89: ల 90: ు 91:  92: 4 93: 1 94: , 95: 8 96: 0
# Context snippet: సత్వ ప్రజలు 41,800 మందికి పైగా
# -----------------------------------------------
# -----------------------------------------------
# 425. ఫైనాన్షియల్ _ క్రైసిస్ _ ఆఫ్ _ 2007% E 2%80% 9308 :
# Question: ఏ సంవత్సరంలో కంప్యూటర్ శాస్త్రవేత్తల బృందం రేటింగ్ ఏజెన్సీలు రూపొందించిన రేటింగ్ల కోసం ఒక నమూనాను నిర్మించింది, అది 2006-2008 లో ఏమి జరిగిందో ఖచ్చితమైనదిగా నిరూపించబడింది?
# Answer: 2005లో
# Start position: 721
# Neighboring characters: 721: 2 722: 0 723: 0 724: 5 725: ల 726: ో 727:  728: క 729: ం 730: ప 731: ్ 732: య
# Context snippet: ంది. 2005లో కంప్
# -----------------------------------------------
# -----------------------------------------------
# 426. పోర్చుగల్ :
# Question: ఏ సంవత్సరంలో ఆర్థిక బెయిలవుట్ కు అంగీకరించబడింది?
# Answer: 2011లో
# Start position: 225
# Neighboring characters: 225: 2 226: 0 227: 1 228: 1 229: ల 230: ో 231:  232: అ 233: ం 234: గ 235: ీ 236: క
# Context snippet: ంది. 2011లో అంగీ
# -----------------------------------------------
# -----------------------------------------------
# 427. మానవతావాదం :
# Question: పునరుజ్జీవనోద్యమ కాలంలో మానవతావాదం యొక్క అసలు విశ్వాసిగా ఎవరు భావించబడ్డారు?
# Answer: పెట్రార్క్
# Start position: 160
# Neighboring characters: 160: ప 161: ె 162: ట 163: ్ 164: ర 165: ా 166: ర 167: ్ 168: క 169: ్ 170: న 171: ు
# Context snippet: -91) పెట్రార్క్ను మొ
# -----------------------------------------------
# -----------------------------------------------
# 428. జియోలాజికల్ _ హిస్టరీ _ ఆఫ్ _ ఎర్త్ :
# Question: దక్షిణ అర్ధగోళంలో ఎక్కువ భాగాన్ని ఏ పెద్ద మహాసముద్రం కప్పేసింది?
# Plausible Answer: పంతలస్సా
# Start position: 631
# Neighboring characters: 631: ప 632: ం 633: త 634: ల 635: స 636: ్ 637: స 638: ా 639:  640: య 641: ొ 642: క
# Context snippet: ంది. పంతలస్సా యొక్
# -----------------------------------------------
# 429. పోలీసులు :
# Question: బో స్ట్రీట్ సమూహానికి వారి ఉద్యోగులు ఎలా జీతం పొందారు?
# Plausible Answer: స్టైపెండరీ వ్యవస్థ వలె
# Start position: 265
# Neighboring characters: 265: స 266: ్ 267: ట 268: ై 269: ప 270: ె 271: ం 272: డ 273: ర 274: ీ 275:  276: వ
# Context snippet: వద్ద స్టైపెండరీ వ్యవస్థ వలె కాకు
# -----------------------------------------------
# 430. జాత్యహంకారం :
# Question: 1948లో జాత్యహంకారాన్ని నిర్వచించి, నిషేధించే అంతర్జాతీయ చట్టాలను ప్రపంచవ్యాప్తంగా ఆమోదించడం ఏ ఒప్పందం ద్వారా ప్రకటించబడింది?
# Answer: జాత్యహంకారాన్ని నిర్వహించారు-అంటే, జాతి మరియు జాతీయ సమూహాలను
# Start position: 630
# Neighboring characters: 630: జ 631: ా 632: త 633: ్ 634: య 635: హ 636: ం 637: క 638: ా 639: ర 640: ా 641: న
# Context snippet: ధంగా జాత్యహంకారాన్ని నిర్వహించారు-అంటే, జాతి మరియు జాతీయ సమూహాలను నిర్
# -----------------------------------------------
# -----------------------------------------------
# 431. సెయింట్ _ బార్త్% C3% A9లేమీ :
# Question: సెయింట్ బార్థెలెమీ హోటళ్లలో ఎన్నింటిలో 15 కంటే తక్కువ గదులు ఉన్నాయి?
# Plausible Answer: 25
# Start position: 28
# Neighboring characters: 28: 2 29: 5 30:  31: హ 32: ో 33: ట 34: ళ 35: ్ 36: ళ 37: ు 38:  39: ఉ
# Context snippet: మారు 25 హోటళ
# -----------------------------------------------
# 432. తజికిస్తాన్ :
# Question: సుమారు 500 బిఈలో ఆధునిక తజికిస్తాన్ భాగం ఏమిటి?
# Answer: అకేమెనిడ్ సామ్రాజ్యంలో
# Start position: 145
# Neighboring characters: 145: అ 146: క 147: ే 148: మ 149: ె 150: న 151: ి 152: డ 153: ్ 154:  155: స 156: ా
# Context snippet: హారం అకేమెనిడ్ సామ్రాజ్యంలో భాగం
# -----------------------------------------------
# -----------------------------------------------
# 433. యూనివర్శిటీ _ ఆఫ్ _ నోట్రే _ డేమ్ :
# Question: ఏ ప్రత్యర్థికి వ్యతిరేకంగా నూట్ రాక్నే తన జట్టుకు "గిప్పర్ కోసం ఒకదాన్ని గెలవండి" అని చెప్పాడు?
# Answer: ఆర్మీ జట్టును
# Start position: 322
# Neighboring characters: 322: ఆ 323: ర 324: ్ 325: మ 326: ీ 327:  328: జ 329: ట 330: ్ 331: ట 332: ు 333: న
# Context snippet: షణను ఆర్మీ జట్టును ఓడిం
# -----------------------------------------------
# -----------------------------------------------
# 434. మానవ శాస్త్రం :
# Question: రిచర్డ్ ఫ్రాన్సిస్ బర్టన్ ఏ సంవత్సరంలో లండన్ ఎథ్నోలాజికల్ సొసైటీ నుండి విడిపోయారు?
# Answer: 1863లో అన్వేషకుడు
# Start position: 48
# Neighboring characters: 48: 1 49: 8 50: 6 51: 3 52: ల 53: ో 54:  55: అ 56: న 57: ్ 58: వ 59: ే
# Context snippet: ుడు. 1863లో అన్వేషకుడు రిచర
# -----------------------------------------------
# -----------------------------------------------
# 435. మోంటానా :
# Question: రాష్ట్రంలో ఏ రకమైన చేపల పెంపకం ఉంది?
# Answer: ట్రౌట్ మరియు కోకనీ సాల్మన్ ఫిషరీస్ ఉన్నాయి,
# Start position: 373
# Neighboring characters: 373: ట 374: ్ 375: ర 376: ౌ 377: ట 378: ్ 379:  380: మ 381: ర 382: ి 383: య 384: ు
# Context snippet: స్సు ట్రౌట్ మరియు కోకనీ సాల్మన్ ఫిషరీస్ ఉన్నాయి, వాల్
# -----------------------------------------------
# -----------------------------------------------
# 436. పంజాబ్, _ పాకిస్తాన్ :
# Question: 2012 జూన్లో విద్యుత్ లేని నగరాలు ఎంతకాలం ఉన్నాయి?
# Answer: నగరాలకు రోజుకు గంటలకొద్దీ
# Start position: 173
# Neighboring characters: 173: న 174: గ 175: ర 176: ా 177: ల 178: క 179: ు 180:  181: ర 182: ో 183: జ 184: ు
# Context snippet: వల్ల నగరాలకు రోజుకు గంటలకొద్దీ విద్
# -----------------------------------------------
# -----------------------------------------------
# 437. రిచ్మండ్, _ వర్జీనియా :
# Question: రిచ్మండ్ యొక్క నేషన్ ఆఫ్ ఇస్లాం సభ్యులు మొదట ఎక్కడ సమావేశమయ్యారు?
# Answer: #24 లో
# Start position: 306
# Neighboring characters: 306: # 307: 2 308: 4 309:  310: ల 311: ో 312:  313: క 314: ల 315: ు 316: స 317: ు
# Context snippet: పుల్ #24 లో కలుస
# -----------------------------------------------
# -----------------------------------------------
# 438. ఇన్ఫెక్షన్. :
# Question: సూక్ష్మజీవులను గుర్తించడానికి అత్యంత సున్నితమైన, నిర్దిష్టమైన మరియు వేగవంతమైన పరీక్షలు ఏ పద్ధతులు ఉపయోగించబడతాయి?
# Answer: సెరోలాజికల్
# Start position: 40
# Neighboring characters: 40: స 41: ె 42: ర 43: ో 44: ల 45: ా 46: జ 47: ి 48: క 49: ల 50: ్ 51:
# Context snippet: ించే సెరోలాజికల్ పద్ధ
# -----------------------------------------------
# -----------------------------------------------
# 439. వేట :
# Question: వేట ఇప్పటికీ ఎక్కడ ముఖ్యమైనది?
# Answer: ఉపాంత వాతావరణాలలో,
# Start position: 412
# Neighboring characters: 412: ఉ 413: ప 414: ా 415: ం 416: త 417:  418: వ 419: ా 420: త 421: ా 422: వ 423: ర
# Context snippet: టికీ ఉపాంత వాతావరణాలలో, ముఖ్
# -----------------------------------------------
# -----------------------------------------------
# 440. ఖాట్మండు :
# Question: ఖాట్మండులో యెంగల్ ఎక్కడ ఉంది?
# Answer: దక్షిణ భాగంలో,
# Start position: 471
# Neighboring characters: 471: ద 472: క 473: ్ 474: ష 475: ి 476: ణ 477:  478: భ 479: ా 480: గ 481: ం 482: ల
# Context snippet: మండు దక్షిణ భాగంలో, మంజు
# -----------------------------------------------
# -----------------------------------------------
# 441. మయోకార్డియల్ ఇన్ఫార్క్షన్ (_ I) :
# Question: సాధారణంగా ఎంఐని గాయంగా పరిగణించేది ఏమిటి?
# Plausible Answer: సాధారణ చట్టంలో,
# Start position: 0
# Neighboring characters: 0: స 1: ా 2: ధ 3: ా 4: ర 5: ణ 6:  7: చ 8: ట 9: ్ 10: ట 11: ం
# Context snippet: సాధారణ చట్టంలో, మయోక
# -----------------------------------------------
# 442. విషయం. :
# Question: పదార్థం యొక్క పరివర్తన సమయంలో ఏ మార్పులు జరుగుతాయి?
# Plausible Answer: పరిమాణం
# Start position: 139
# Neighboring characters: 139: ప 140: ర 141: ి 142: మ 143: ా 144: ణ 145: ం 146: , 147:  148: అ 149: ం 150: ట
# Context snippet: బడిన పరిమాణం, అంట
# -----------------------------------------------
